# %% [markdown]
# <center><h1>Exploring Semantic Chunking Methods</h1></center>

# %% [markdown]
# This notebook explores three semantic chunking techniques, which are crucial for breaking text into meaningful units. We will implement and compare these techniques to assess their performance and suitability for text generation.

# %% [markdown]
# ### **Table of Contents**
#
# * [Section 1. Install Libraries](#section-one)
# * [Section 2. Import Libraries](#section-two)
# * [Section 3. Load Data](#section-three)
# * [Section 4. Load Embedding Model](#section-four)
# * [Section 5. Testing Different Chunking Techniques](#section-five)
#     *     [Statistical Chunking](#section-six)
#     *     [Consecutive Chunking](#section-seven)
#     *     [Cumulative Chunking](#section-eight)
# * [Section 6. Conclusion](#section-nine)

# %% [markdown]
# ## **Step 1. Install Libraries** <a id="section-one"></a>

# %%
# %%capture
# !pip install -qU semantic-chunkers
# !pip install -qU datasets==2.19.1
# !pip install -qU langchain 
# !pip install -qU pypdf
# !pip install -qU langchain-community

# %% [markdown]
# ## **Step 2. Import Libraries** <a id="section-two"></a>

# %%
from datasets import load_dataset
from semantic_router.encoders import HuggingFaceEncoder
from semantic_chunkers import StatisticalChunker
from semantic_chunkers import ConsecutiveChunker
from semantic_chunkers import CumulativeChunker
from langchain_community.document_loaders import PyPDFLoader

# %% [markdown]
# ## **Step 3. Load Data** <a id="section-three"></a>

# %% [markdown]
# In this notebook, we will use the [2024 NVIDIA annual report](https://investor.nvidia.com/financial-info/annual-reports-and-proxies/default.aspx) in PDF format. We will parse it using the PyPDFLoader function from LangChain. The text in the NVIDIA report is straightforward to parse and does not require OCR for text extraction. Our focus here is on testing different semantic chunking techniques, rather than exploring various data extraction methods.

# %%
file_path = (
    "/kaggle/input/nvidia-annual-report/NVIDIA-2024-Annual-Report.pdf"
)
loader = PyPDFLoader(file_path)
pages = loader.load_and_split()

pages[0]
# Out:
# Document(metadata={'source': '/kaggle/input/nvidia-annual-report/NVIDIA-2024-Annual-Report.pdf', 'page': 0}, page_content='2024  \nNVIDIA Corporation\nAnnual Review  \n \nNotice of Annual Meeting \nProxy Statement  \nForm 10-K')

# %%
pages[0:2]
# Out:
# [Document(metadata={'source': '/kaggle/input/nvidia-annual-report/NVIDIA-2024-Annual-Report.pdf', 'page': 0}, page_content='2024  \nNVIDIA Corporation\nAnnual Review  \n \nNotice of Annual Meeting \nProxy Statement  \nForm 10-K'),
#  Document(metadata={'source': '/kaggle/input/nvidia-annual-report/NVIDIA-2024-Annual-Report.pdf', 'page': 2}, page_content='“The sum of all that \nNVIDIA’s doing \nwill indeed create \nthe next industrial \nrevolution”\nCNBC\nAccelerated computing is sustainable \ncomputing.  Every data center in the world \nneeds to be accelerated to reclaim power, \nachieve sustainability, and realize net-zero \nemissions. Accelerated data centers could save \nan incredible 19 terawatt-hours of electricity \nannually if run on GPU and DPU accelerators vs \nCPUs. That’s about the same energy as a year’s \nworth of trips by 2.9 million passenger cars. \nThe efficiency of accelerated computing \npaved the way for generative AI. The most \ncritical computing platform of our generation, \ngenerative AI will reshape the world’s largest \nindustries and create an entirely new one.\nNVIDIA, the pioneer of accelerated computing, \nis the driving force of this new era.')]

# %%
content_list = []
for page in pages:
    content_list.append(page.page_content)
content = ''.join(content_list)
len(content)
# Out:
# 656803

# %%
type(content)
# Out:
# str

# %%
content = content[:20_000]

# %%
len(content)
# Out:
# 20000

# %% [markdown]
# ## **Step 4. Load Embedding Model** <a id="section-four"></a>

# %%
encoder = HuggingFaceEncoder(name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]

# %% [markdown]
# ## **Step 5. Testing Different Chunking Techniques** <a id="section-five"></a>

# %% [markdown]
# ### **Statistical Chunking** <a id="section-six"></a>

# %% [markdown]
# For Statistical Chunking, this technique automatically calculates the score threshold. As our most robust chunking method, it uses a dynamic similarity threshold to identify local similarity splits, balancing accuracy and efficiency. The StatisticalChunker can automatically determine an optimal threshold value, reducing the need for extensive customization compared to other chunking methods. Additionally, this technique allows for parameter adjustments, such as setting the maximum and minimum token numbers for each split.

# %%
chunker = StatisticalChunker(
    encoder=encoder,
    #min_split_tokens=200,
    #max_split_tokens=500,
)

# %%
chunks = chunker(docs=[content])
# Out:
# 2024-07-10 19:42:26 INFO semantic_chunkers.utils.logger Single document exceeds the maximum token limit of 300. Splitting to sentences before semantically merging.
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
chunker.print(chunks[0])
# Out:
# Split 1, tokens 127, triggered by: 0.14
# 2024 NVIDIA Corporation Annual Review Notice of Annual Meeting Proxy Statement Form 10-K“The sum of all that NVIDIA’s doing will indeed create the next industrial revolution” CNBC Accelerated computing is sustainable computing. Every data center in the world needs to be accelerated to reclaim power, achieve sustainability, and realize net-zero emissions. Accelerated data centers could save an incredible 19 terawatt-hours of electricity annually if run on GPU and DPU accelerators vs CPUs. That’s about the same energy as a year’s worth of trips by 2.9 million passenger cars. The efficiency of accelerated computing
# ----------------------------------------------------------------------------------------
#
#
# Split 2, tokens 125, triggered by: 0.12
# paved the way for generative AI. The most critical computing platform of our generation, generative AI will reshape the world’s largest industries and create an entirely new one. NVIDIA, the pioneer of accelerated computing, is the driving force of this new era.HGX B100 NVLINK Switch GB200 Superchip Compute Node“They basically have a comprehensive solution from the chip all the way to data centers at this point” CIO Accelerated computing starts with the most advanced processors and ends with AI factories. From chip architecture to advanced networking to acceleration libraries, NVIDIA builds the entire computing system at data-center scale.
# ----------------------------------------------------------------------------------------
#
#
# Split 3, tokens 121, triggered by: 0.19
# Then, we disaggregate everything and reintegrate it into the world’s computing fabric so that industries can leverage the parts and systems they need. In the future, almost all of our experiences will be generative. Blackwell—the world’s most powerful AI platform—is tailor-made for the generative AI revolution. Quantum X800 Switch ConnectX-8 SuperNICSpectrum X800 Switch BlueField-3 SuperNIC“Continually optimized software remains NVIDIA’s ace in the hole” Forbes Accelerated computing requires full-stack software. NVIDIA’s acceleration stacks optimize workloads on a massive scale, integrating
# ----------------------------------------------------------------------------------------
#
#
# Split 4, tokens 118, triggered by: 0.10
# thousands of nodes while treating network and storage as integral components. This year, we rolled out TensorRT-LLM and NVIDIA Inference Microservices™ (NIM). TensorRT-LLM is an open-source software library that enables customers to more than double the inference performance of their GPUs. NIM are a new way to package and deliver AI software. This curated selection of microservices adds a new layer to NVIDIA’s full-stack computing platform— connecting the AI ecosystem of model developers, platform providers, and enterprises with a standardized path to run custom AI models.Industry Standard APIs
# ----------------------------------------------------------------------------------------
#
#
# Split 5, tokens 172, triggered by: 0.13
# Text, Speech, Image, Video, 3D, Biology Triton Inference Server cuDF, CV-CUDA, DALI, NCCL, Post Processing Decoder Cloud Native Stack GPU Operator, Network Operator Enterprise Management GPU Health Check, Identity, Metrics, Monitoring, Secrets Management Kubernetes 100’s of Millions of CUDA GPUs Installed BaseTensorRT LLM and Triton cuBLAS , cuDNN, In-Flight Batching, Memory Optimization, FP8 Quantization Optimized Model Single GPU, Multi-GPU, Multi-Node Customization Cache P-Tuning, LORA, Model Weights NVIDIA CUDA 100’s of Millions of CUDA GPUs Installed BaseDATA PROCESSING DSLCAD, CAE, SDA DSLPERFORMANCE, ECOSYSTEM, REACH DEMANDINSTALLED BASE APPSGENOMICS, DRUG DISCOVERY DSL
# ----------------------------------------------------------------------------------------
#
#
# Split 6, tokens 119, triggered by: 0.13
# CUDA-X LIBRARIES ONE ARCHITECTURE-CUDASUPERCOMPUTING SYSTEMS AND SOFTWARE GPU SWITCH NIC/DPU CPUWEATHER SIMULATION DSL6G, QUANTUM DSLAV, ROBOTICS, INDUSTRIAL DIGITAL TWINS DSLGENERATIVE AI DSL DATACENTERS HGX MGXCLOUD DGX CLOUD OV CLOUDEDGE AGX IGXDATA PROCESSING DSLCAD, CAE, SDA DSLPERFORMANCE, ECOSYSTEM, REACH DEMANDINSTALLED BASE APPSGENOMICS, DRUG DISCOVERY DSL
# ----------------------------------------------------------------------------------------
#
#
# Split 7, tokens 103, triggered by: 0.19
# CUDA-X LIBRARIES ONE ARCHITECTURE-CUDASUPERCOMPUTING SYSTEMS AND SOFTWARE GPU SWITCH NIC/DPU CPUWEATHER SIMULATION DSL6G, QUANTUM DSLAV, ROBOTICS, INDUSTRIAL DIGITAL TWINS DSLGENERATIVE AI DSL DATACENTERS HGX MGXCLOUD DGX CLOUD OV CLOUDEDGE AGX IGX“NVIDIA’s got great chips, and more importantly, they have an incredible ecosystem”
# ----------------------------------------------------------------------------------------
#
#
# Split 8, tokens 116, triggered by: 0.12
# The New York Times NVIDIA’s accelerated computing ecosystem is bringing AI to every enterprise. The NVIDIA ecosystem spans nearly 5 million  developers and 40,000  companies. More than 1,600 generative AI companies are building on NVIDIA. CUDA®, our parallel computing model launched in 2006, offers developers more than 300  libraries, 600  AI models, numerous SDKs, and 3,500  GPU-accelerated applications. CUDA has more than 48 million  downloads.“NVIDIA’s prescription for the future:
# ----------------------------------------------------------------------------------------
#
#
# Split 9, tokens 133, triggered by: 0.18
# transforming healthcare with AI” Forbes NVIDIA AI is powering the next era of drug discovery and advances in life sciences. NVIDIA Clara™, our suite of computing platforms, software, and services for healthcare and life sciences, and NVIDIA BioNeMo™, our platform for state-of-the-art generative AI models for drug discovery, are turbocharging breakthroughs. Genentech is tapping NVIDIA to use generative AI to discover and develop new therapeutics and deliver treatments to patients more efficiently. Recursion Pharmaceuticals is the first NVIDIA partner to offer an AI model through BioNeMo cloud APIs. And Amgen is building AI models trained
# ----------------------------------------------------------------------------------------
#
#
# Split 10, tokens 149, triggered by: 0.19
# to analyze one of the world’s most extensive human datasets on an NVIDIA DGX SuperPOD™.“NVIDIA has virtually recreated the entire planet—and now it wants to use its digital twin to crack weather forecasting for good” TechRadar NVIDIA AI is tackling climate change. Extreme events attributable to climate change cost more than $143 billion a year. NVIDIA’s CorrDiff is a revolutionary new generative AI model trained on high-resolution radar, weather forecasts, and other data. Using CorrDiff, extreme weather events can be super-resolved from 25-kilometer to two-kilometer resolution with 1,000 times the speed and 3,000 times the energy efficiency of conventional weather
# ----------------------------------------------------------------------------------------
#
#
# Split 11, tokens 109, triggered by: 0.20
# models. This AI-powered weather forecasting allows us to more accurately predict and track severe storms to try and reduce those impacts.“NVIDIA is a core technology leader in the autonomous driving arena” CleanTechnica NVIDIA AI is revolutionizing transportation. NVIDIA has developed an end-to-end platform from cloud to car to allow the automotive ecosystem to develop industry-leading AI- defined vehicles. We recently announced DRIVE AGX Thor™—designed and optimized for gen AI utilizing NVIDIA’s Blackwell architecture— to reimagine the driving experience.
# ----------------------------------------------------------------------------------------
#
#
# Split 12, tokens 150, triggered by: 0.08
# And this year, every next-generation Mercedes-Benz vehicle will include an NVIDIA software-defined computing architecture that includes the most powerful computer, system software, and applications for consumers.“The age of humanoid robots could be a significant step closer thanks to a new release from NVIDIA” TechRadar NVIDIA is fueling the next wave of AI—robotics and industrial digitalization. And that new wave of robots that will learn in NVIDIA Omniverse. Simulators like Isaac Sim running on Omniverse will be gyms where robots learn their skills. Over 1.2 million developers and 10,000 customers and partners are leveraging the NVIDIA Isaac and Jetson platforms to create and deploy AI-driven robots. And Project GR00T, a
# ----------------------------------------------------------------------------------------
#
#
# Split 13, tokens 120, triggered by: 0.19
# general-purpose foundation model for humanoid robots, will help them understand natural language and emulate movements by observing human actions.“NVIDIA Omniverse Cloud APIs will elevate digital twins for a new industrial revolution” Venture Beat The soul of NVIDIA is where computer graphics, physics, and AI intersect in Omniverse—a virtual world simulation engine. Heavy industry is one of the final frontiers of IT. Omniverse is the fundamental operating system for building digital twins that are crucial to unlocking new potential in heavy industries worldwide. Omniverse connects the tools created by developers in the NVIDIA ecosystem. It enables
# ----------------------------------------------------------------------------------------
#
#
# Split 14, tokens 112, triggered by: 0.12
# each team to operate on the same ground truth, creating efficiencies and innovation. And now, with NVIDIA Omniverse Cloud™ APIs, developers can simplify and speed up the development of digital twins for almost any industrial application, seamlessly integrating Omniverse into their existing apps.“Generative AI is the defining technology of our time. Blackwell is the engine to power this new industrial revolution. Working with the most dynamic companies in the world, we will realize the promise of AI for every industry.”The dawn of a new computing era is unmistakably upon us.
# ----------------------------------------------------------------------------------------
#
#
# Split 15, tokens 126, triggered by: 0.16
# Two transitions are occurring simultaneously—accelerated computing and generative AI—transforming the computer industry and every other industry worldwide. CPU scaling, the engine that has driven the computer industry over the past three decades, has slowed. Software developers have turned to accelerated computing to keep pace with the exponentially growing demand for computing in a cost- and energy-sustainable way. The computing model pioneered by NVIDIA has reached critical mass and has been adopted broadly as the path forward. Accelerated computing will modernize the world’s trillion-dollar data center infrastructure. Its increased throughput and cost and energy savings are remarkable.
# ----------------------------------------------------------------------------------------
#
#
# Split 16, tokens 131, triggered by: 0.25
# Two NVIDIA HGX computers with Hopper GPUs that together cost $500K can replace 1,000 nodes of CPU servers that cost $10M for AI, scientific computing, or data processing workloads. For data centers that are budget- or power-limited, NVIDIA delivers an order- of-magnitude increase in throughput. For data centers optimized for throughput, NVIDIA delivers an order-of- magnitude reduction in cost and power. Accelerated computing is the best way to build sustainable data centers. When the cost of a fundamental resource, like computing, improves by orders of magnitude, new methods are invented, and new utilities are discovered. AI researchers tapped
# ----------------------------------------------------------------------------------------
#
#
# Split 17, tokens 173, triggered by: 0.20
# NVIDIA CUDA to realize deep learning, a machine learning algorithm that is incredibly compute-intensive. Deep learning processes mountains of data to find patterns and relationships and learn predictive features. In 2012, AlexNet shocked the artificial intelligence community by winning, by a considerable margin, the ImageNet computer vision contest. Within a couple of years, every computer vision algorithm used deep learning, and within five years, computer vision had achieved superhuman object recognition capabilities. AlexNet on NVIDIA CUDA was the big bang of modern AI. We recognized that AlexNet was more than a computer vision breakthrough. We imagined deep learning would fundamentally revolutionize software and, consequently, all computing. Deep learning can scale to tackle many previously impossible challenges with new network architecture innovations, more data, and more compute. In the ensuing decade, NVIDIA set out to advance AI.
# ----------------------------------------------------------------------------------------
#
#
# Split 18, tokens 112, triggered by: 0.23
# We pursued several strategies:Reinvent every layer of computing , from GPU architecture, e.g., Tensor Cores, to system interconnect, e.g., NVLink, systems, e.g., DGX, software, e.g., cuDNN and TensorRT, to networking technologies, e.g., SHARP in-networking processing, and much more. We reinvented computing from the ground up. Transform into a data-center-scale company  by combining with Mellanox, the world’s leading high-performance networking company. As computing
# ----------------------------------------------------------------------------------------
#
#
# Split 19, tokens 166, triggered by: 0.15
# large models and training data scales to require millions of trillions more operations, we need not just amazing chips but AI supercomputing systems. Today, NVIDIA is an expert at every computing layer, from chips to software, and across the data center —compute to networking. We have the expertise and scale to help customers build AI infrastructures anywhere. Become an AI expert by building NVIDIA AI Research and application-specific AI platforms—full-stack AI platforms for DLSS RTX neural graphics, DRIVE AV self-driving cars, Isaac robotics, ACE digital humans, NeMo LLMs, BioNeMo digital biology, and Clara medical imaging—so that we can apply AI firsthand to create new markets. Automotive has joined gaming as a multi-billion-dollar run rate business. Healthcare and robotics are additional multi-billion-dollar opportunities.
# ----------------------------------------------------------------------------------------
#
#
# Split 20, tokens 132, triggered by: 0.11
# Dear NVIDIANs and Stakeholders,Build a new ecosystem for the AI era by creating tools, libraries, and expert technical teams to support developers going after the AI revolution. The global NVIDIA ecosystem now approaches 5 million developers—capping a record- setting year for new developers. Forty thousand companies have worked with NVIDIA. There are now more than 3,300 GPU-accelerated applications. More than 18,000 startups are building on NVIDIA. These four strategies—reinventing the full computing stack, building data-center-scale AI supercomputers, conducting basic AI research and applying AI to create new markets, and building
# ----------------------------------------------------------------------------------------
#
#
# Split 21, tokens 122, triggered by: 0.22
# a global ecosystem—transformed NVIDIA and all of computing. Twelve years after AlexNet, NVIDIA is a full-stack, data-center-scale AI company that partners with nearly every AI company in every industry worldwide. Then ChatGPT arrived, and the pace of AI accelerated even faster. The era of generative AI began. Computers can now generate information based on human prompts. At the heart of ChatGPT, large language models, or LLMs, learned to understand human language, prior knowledge, and even some common sense from massive amounts of text. And not only human language.
# ----------------------------------------------------------------------------------------
#
#
# Split 22, tokens 110, triggered by: 0.16
# LLMs have learned to understand text, speech, images, and even amino acids and proteins, the language of biology. With multi-modal learning—for example, simultaneously learning from language and images—generative AI is gaining a deeper understanding of the world and can translate across different modalities. Given a prompt such as “ golden retriever wearing sunglasses and a white golden doodle with black leather jacket surfing a wave, on a surfboard with NVIDIA logo, in Maui during sunset, with hotels on the beach ,”
# ----------------------------------------------------------------------------------------
#
#
# Split 23, tokens 174, triggered by: 0.13
# generative AI can create an image. From an amino acid sequence, AI can generate the structure of a protein, e.g., the SARS-CoV-2 main protease. The combinations and possibilities are endless. Generative AI is the most transformative and consequential technology of our generation. Computers will understand people and the world and perform tasks that previously required human intelligence. With generative AI, computers can augment and amplify humans to perform tasks with greater ease and speed, help us be more productive, and solve problems previously unimaginable. Researchers use generative AI to compose billions of chemical compounds and virtually test them as drugs against a disease target. Climate scientists are using generative AI to map tens of thousands of potential trajectories of a weather pattern in seconds to predict the path of a deadly storm better. The automation of intelligence with generative AI will transform every
# ----------------------------------------------------------------------------------------
#
#
# Split 24, tokens 111, triggered by: 0.24
# company in the world’s $100 trillion worth of industries. Startups and established companies spanning every conceivable domain and industry are investing billions of dollars to advance and apply generative AI. With AI supercomputers, we are manufacturing intelligence in the form of tokens or floating-point numbers. In the last industrial revolution, power generation plants produced electricity. In this new industrial revolution, NVIDIA AI supercomputers are the AI factories that produce intelligence. Generative AI has enabled us to produce something completely new. Companies will operate a new type
# ----------------------------------------------------------------------------------------
#
#
# Split 25, tokens 109, triggered by: 0.21
# of facility, owned or rented, that produces AI to augment, accelerate, and amplify the productivity of their employees and business processes. Nations have awakened to AI’s impact. Countries are building sovereign AI infrastructures. Governments see AI factories as essential infrastructure to advance their society and local industries. Nations such as Canada, France, India, Singapore, Japan, and others seek to develop their sovereign AI capabilities as they have recognized their country’s data is their most valuable natural resource.Generative AI is the most impactful
# ----------------------------------------------------------------------------------------
#
#
# Split 26, tokens 106, triggered by: -0.03
# invention of our time, and as with electricity and the internet, it impacts everyone and every industry. The potential of AI to help tackle the world’s most pressing challenges is incredible. To maximize this potential, companies, governments, and societies are raising awareness of the capabilities of this technology, inventing capabilities to align, guardrail, secure, and control models, sharing best practices, creating new policies, discovering new social norms, encouraging debate, and inspiring whole new areas of research in AI security and safety.
# ----------------------------------------------------------------------------------------
#
#
# Split 27, tokens 106, triggered by: 0.23
# NVIDIA Accelerated Computing Reaches the Tipping Point For fiscal 2024, revenue was up 126% to a record $60.9 billion. GAAP earnings per diluted share was $11.93, up 586% from a year ago. Non-GAAP earnings per diluted share were $12.96, up 288% from a year ago. Non-GAAP gross margin was 73.8%. Full-year Data Center revenue rose 217% to a record $47.5 billion.
# ----------------------------------------------------------------------------------------
#
#
# Split 28, tokens 120, triggered by: 0.24
# Demand for Hopper architecture products remains strong, and we have announced the Blackwell architecture, its successor.Full-year Gaming revenue rose 15% to $10.4 billion on strong demand for our expanded GeForce RTX 40 Series GPU lineup. Full-year revenue for Professional Visualization rose 1% to $1.6 billion. Automotive full-year revenue this year rose 21% to $1.1 billion. A trillion dollars’ worth of existing data centers needs to be accelerated, and a trillion more dollars is needed to expand the installed base with AI factories in the next five years.
# ----------------------------------------------------------------------------------------
#
#
# Split 29, tokens 128, triggered by: 0.12
# We are in the middle of one of the most significant expansions in computing history. NVIDIA is well-positioned to help our customers and partners realize this opportunity. We hosted GTC live and in person for the first time in five years. It was an electric experience. Over 1,100 sessions, more than 300 exhibits, and 20-plus technical workshops packed the San Jose Convention Center to capacity, providing learning and networking opportunities for our community and ecosystem unavailable anywhere else. Just 15 years ago, GTC easily fit inside a hotel ballroom. Now, it is a can’t-
# ----------------------------------------------------------------------------------------
#
#
# Split 30, tokens 151, triggered by: 0.16
# miss event with more than 19,000 in-person registrations, almost 300,000 virtual registrations, and more than 12,000 people at the SAP Center for our keynote, which kicked off an unbelievable week. Our industry partners’ unprecedented collaboration and participation made this year’s GTC exceptional. The presence of industry giants like Amazon, Cisco, Dell, Google, HPE, IBM, Lenovo, Microsoft, Oracle, and Supermicro at GTC underscored the universal recognition of this moment in technology and their commitment to shaping the future alongside NVIDIA. So, what now? How are we raising the bar? A New Computing Platform for the New Industrial Revolution We are accelerating our roadmap across the board. Generative AI models
# ----------------------------------------------------------------------------------------
#
#
# Split 31, tokens 112, triggered by: 0.14
# are increasing exponentially in scale, doubling about every six months. If it takes twice as much data to train models twice as large, compute intensity is growing at 4X every six months. Further, the demand for inferencing, or generating AI, on NVIDIA has increased tremendously. When you interact with a chatbot, which every application or service will integrate in the future, you are likely interacting directly with an NVIDIA GPU in the cloud. In the future, our interactions with computers will be generated by AI specifically for that interaction rather
# ----------------------------------------------------------------------------------------
#
#
# Split 32, tokens 105, triggered by: 0.15
# than retrieved prerecorded text or content. Generative AI will let us reinvent how we interact with computers, and demand for GPUs will be massive. Multi-modality, large context windows, retrieval-augmented generation, mixture-of-experts, synthetic data generation, content protection, reasoning, planning, tool use, physical world understanding, trillion-parameterLLMs, distillation to small models, high throughput to high interactivity—the innovation rate of training and inference is incredibly high. Advances are
# ----------------------------------------------------------------------------------------
#
#
# Split 33, tokens 1, triggered by: final split
# c
# ----------------------------------------------------------------------------------------

# %% [markdown]
# ### **Consecutive Chunking** <a id="section-seven"></a>

# %% [markdown]
# For the Consecutive Chunking method, we begin by splitting the text into smaller sentences. These sentences are then merged to form larger chunks. If there is a drop in the similarity score below a predefined threshold which is `score_threshold`, the merging process stops. The sentences merged up to that point, which have maintained a similarity score above the threshold, are considered a single chunk. We then start forming the next chunk with the remaining sentences. This approach ensures that only similar sentences are grouped together, improving the coherence of each chunk.

# %%
chunker = ConsecutiveChunker(
    encoder=encoder, 
    score_threshold=0.2 # 
)

# %%
chunks = chunker(docs=[content])
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/649 [00:00<?, ?it/s]

# %%
chunker.print(chunks[0])
# Out:
# Split 1, tokens None, triggered by: 0.10
# 2024
# ----------------------------------------------------------------------------------------
#
#
# Split 2, tokens None, triggered by: 0.14
# NVIDIA Corporation Annual Review Notice of Annual Meeting
# ----------------------------------------------------------------------------------------
#
#
# Split 3, tokens None, triggered by: 0.08
# Proxy Statement
# ----------------------------------------------------------------------------------------
#
#
# Split 4, tokens None, triggered by: 0.08
# Form 10-K“The sum of all that
# ----------------------------------------------------------------------------------------
#
#
# Split 5, tokens None, triggered by: 0.17
# NVIDIA’s doing
# ----------------------------------------------------------------------------------------
#
#
# Split 6, tokens None, triggered by: 0.04
# will indeed create the next industrial revolution”
# ----------------------------------------------------------------------------------------
#
#
# Split 7, tokens None, triggered by: 0.10
# CNBC
# ----------------------------------------------------------------------------------------
#
#
# Split 8, tokens None, triggered by: 0.06
# Accelerated computing is sustainable computing. Every data center in the world
# ----------------------------------------------------------------------------------------
#
#
# Split 9, tokens None, triggered by: 0.15
# needs to be accelerated to reclaim power, achieve sustainability, and realize net-zero emissions.
# ----------------------------------------------------------------------------------------
#
#
# Split 10, tokens None, triggered by: 0.19
# Accelerated data centers could save
# ----------------------------------------------------------------------------------------
#
#
# Split 11, tokens None, triggered by: 0.14
# an incredible 19 terawatt-hours of electricity annually if run on GPU and DPU accelerators vs CPUs. That’s about the same energy as a year’s worth of trips by 2.9 million passenger cars.
# ----------------------------------------------------------------------------------------
#
#
# Split 12, tokens None, triggered by: 0.17
# The efficiency of accelerated computing
# ----------------------------------------------------------------------------------------
#
#
# Split 13, tokens None, triggered by: 0.15
# paved the way for generative AI.
# ----------------------------------------------------------------------------------------
#
#
# Split 14, tokens None, triggered by: 0.05
# The most
# ----------------------------------------------------------------------------------------
#
#
# Split 15, tokens None, triggered by: -0.02
# critical computing platform of our generation, generative AI will reshape the world’s largest industries and create an entirely new one. NVIDIA, the pioneer of accelerated computing, is the driving force of this new era.HGX B100 NVLINK Switch GB200 Superchip
# ----------------------------------------------------------------------------------------
#
#
# Split 16, tokens None, triggered by: 0.05
# Compute Node“They basically have
# ----------------------------------------------------------------------------------------
#
#
# Split 17, tokens None, triggered by: 0.10
# a comprehensive
# ----------------------------------------------------------------------------------------
#
#
# Split 18, tokens None, triggered by: 0.16
# solution from the chip
# ----------------------------------------------------------------------------------------
#
#
# Split 19, tokens None, triggered by: 0.12
# all the way to data centers at this point” CIO
# ----------------------------------------------------------------------------------------
#
#
# Split 20, tokens None, triggered by: 0.16
# Accelerated computing starts with the most advanced processors and ends with AI factories. From chip architecture to advanced networking
# ----------------------------------------------------------------------------------------
#
#
# Split 21, tokens None, triggered by: 0.15
# to acceleration libraries, NVIDIA builds the entire
# ----------------------------------------------------------------------------------------
#
#
# Split 22, tokens None, triggered by: 0.02
# computing system at data-center scale.
# ----------------------------------------------------------------------------------------
#
#
# Split 23, tokens None, triggered by: 0.13
# Then, we
# ----------------------------------------------------------------------------------------
#
#
# Split 24, tokens None, triggered by: 0.15
# disaggregate everything and reintegrate it into
# ----------------------------------------------------------------------------------------
#
#
# Split 25, tokens None, triggered by: 0.19
# the world’s computing fabric so that industries can leverage the parts and systems they need.
# ----------------------------------------------------------------------------------------
#
#
# Split 26, tokens None, triggered by: 0.16
# In the future, almost all of our experiences will be generative.
# ----------------------------------------------------------------------------------------
#
#
# Split 27, tokens None, triggered by: -0.01
# Blackwell—the world’s most powerful AI platform—is tailor-made for the generative AI revolution.
# ----------------------------------------------------------------------------------------
#
#
# Split 28, tokens None, triggered by: 0.16
# Quantum X800 Switch ConnectX-8 SuperNICSpectrum X800 Switch
# ----------------------------------------------------------------------------------------
#
#
# Split 29, tokens None, triggered by: 0.01
# BlueField-3 SuperNIC“Continually
# ----------------------------------------------------------------------------------------
#
#
# Split 30, tokens None, triggered by: 0.17
# optimized software
# ----------------------------------------------------------------------------------------
#
#
# Split 31, tokens None, triggered by: 0.06
# remains NVIDIA’s
# ----------------------------------------------------------------------------------------
#
#
# Split 32, tokens None, triggered by: 0.13
# ace in the hole”
# ----------------------------------------------------------------------------------------
#
#
# Split 33, tokens None, triggered by: 0.14
# Forbes
# ----------------------------------------------------------------------------------------
#
#
# Split 34, tokens None, triggered by: 0.20
# Accelerated computing requires full-stack
# ----------------------------------------------------------------------------------------
#
#
# Split 35, tokens None, triggered by: 0.10
# software.
# ----------------------------------------------------------------------------------------
#
#
# Split 36, tokens None, triggered by: 0.04
# NVIDIA’s acceleration stacks optimize workloads on a massive scale, integrating thousands of nodes while treating network
# ----------------------------------------------------------------------------------------
#
#
# Split 37, tokens None, triggered by: 0.15
# and storage as integral components.
# ----------------------------------------------------------------------------------------
#
#
# Split 38, tokens None, triggered by: 0.18
# This year, we rolled out TensorRT-LLM and NVIDIA
# ----------------------------------------------------------------------------------------
#
#
# Split 39, tokens None, triggered by: 0.16
# Inference Microservices™ (NIM).
# ----------------------------------------------------------------------------------------
#
#
# Split 40, tokens None, triggered by: 0.05
# TensorRT-LLM
# ----------------------------------------------------------------------------------------
#
#
# Split 41, tokens None, triggered by: -0.03
# is an open-source software library that enables
# ----------------------------------------------------------------------------------------
#
#
# Split 42, tokens None, triggered by: 0.11
# customers to more than double the inference
# ----------------------------------------------------------------------------------------
#
#
# Split 43, tokens None, triggered by: 0.19
# performance of their GPUs.
# ----------------------------------------------------------------------------------------
#
#
# Split 44, tokens None, triggered by: 0.15
# NIM are a new way
# ----------------------------------------------------------------------------------------
#
#
# Split 45, tokens None, triggered by: 0.17
# to package and deliver AI software. This curated
# ----------------------------------------------------------------------------------------
#
#
# Split 46, tokens None, triggered by: 0.05
# selection of microservices adds a new layer
# ----------------------------------------------------------------------------------------
#
#
# Split 47, tokens None, triggered by: 0.10
# to NVIDIA’s full-stack computing platform—
# ----------------------------------------------------------------------------------------
#
#
# Split 48, tokens None, triggered by: 0.19
# connecting the AI ecosystem of model developers, platform providers, and enterprises with a
# ----------------------------------------------------------------------------------------
#
#
# Split 49, tokens None, triggered by: 0.07
# standardized path to run custom AI models.Industry Standard APIs
# ----------------------------------------------------------------------------------------
#
#
# Split 50, tokens None, triggered by: 0.08
# Text, Speech, Image, Video, 3D, Biology
# ----------------------------------------------------------------------------------------
#
#
# Split 51, tokens None, triggered by: 0.14
# Triton Inference Server
# ----------------------------------------------------------------------------------------
#
#
# Split 52, tokens None, triggered by: 0.11
# cuDF, CV-CUDA, DALI, NCCL,
# ----------------------------------------------------------------------------------------
#
#
# Split 53, tokens None, triggered by: 0.04
# Post Processing Decoder
# ----------------------------------------------------------------------------------------
#
#
# Split 54, tokens None, triggered by: 0.09
# Cloud Native Stack
# ----------------------------------------------------------------------------------------
#
#
# Split 55, tokens None, triggered by: 0.06
# GPU Operator, Network Operator
# ----------------------------------------------------------------------------------------
#
#
# Split 56, tokens None, triggered by: 0.06
# Enterprise Management
# ----------------------------------------------------------------------------------------
#
#
# Split 57, tokens None, triggered by: 0.08
# GPU Health Check, Identity, Metrics, Monitoring, Secrets Management Kubernetes
# ----------------------------------------------------------------------------------------
#
#
# Split 58, tokens None, triggered by: 0.12
# 100’s of Millions of CUDA GPUs Installed BaseTensorRT LLM and Triton cuBLAS , cuDNN, In-Flight Batching, Memory Optimization, FP8 Quantization Optimized Model
# ----------------------------------------------------------------------------------------
#
#
# Split 59, tokens None, triggered by: 0.03
# Single GPU, Multi-GPU, Multi-Node
# ----------------------------------------------------------------------------------------
#
#
# Split 60, tokens None, triggered by: 0.07
# Customization Cache
# ----------------------------------------------------------------------------------------
#
#
# Split 61, tokens None, triggered by: 0.02
# P-Tuning, LORA, Model Weights
# ----------------------------------------------------------------------------------------
#
#
# Split 62, tokens None, triggered by: 0.19
# NVIDIA CUDA 100’s of Millions of CUDA GPUs Installed BaseDATA
# ----------------------------------------------------------------------------------------
#
#
# Split 63, tokens None, triggered by: 0.15
# PROCESSING DSLCAD, CAE, SDA DSLPERFORMANCE, ECOSYSTEM, REACH DEMANDINSTALLED BASE APPSGENOMICS,
# ----------------------------------------------------------------------------------------
#
#
# Split 64, tokens None, triggered by: 0.04
# DRUG DISCOVERY DSL
# ----------------------------------------------------------------------------------------
#
#
# Split 65, tokens None, triggered by: 0.08
# CUDA-X LIBRARIES ONE ARCHITECTURE-CUDASUPERCOMPUTING SYSTEMS AND SOFTWARE GPU SWITCH NIC/DPU CPUWEATHER
# ----------------------------------------------------------------------------------------
#
#
# Split 66, tokens None, triggered by: 0.07
# SIMULATION
# ----------------------------------------------------------------------------------------
#
#
# Split 67, tokens None, triggered by: 0.06
# DSL6G,
# ----------------------------------------------------------------------------------------
#
#
# Split 68, tokens None, triggered by: 0.11
# QUANTUM
# ----------------------------------------------------------------------------------------
#
#
# Split 69, tokens None, triggered by: 0.17
# DSLAV, ROBOTICS, INDUSTRIAL DIGITAL
# ----------------------------------------------------------------------------------------
#
#
# Split 70, tokens None, triggered by: 0.13
# TWINS
# ----------------------------------------------------------------------------------------
#
#
# Split 71, tokens None, triggered by: 0.19
# DSLGENERATIVE AI
# ----------------------------------------------------------------------------------------
#
#
# Split 72, tokens None, triggered by: 0.19
# DSL DATACENTERS
# ----------------------------------------------------------------------------------------
#
#
# Split 73, tokens None, triggered by: 0.15
# HGX MGXCLOUD DGX CLOUD OV CLOUDEDGE AGX IGXDATA PROCESSING DSLCAD, CAE, SDA DSLPERFORMANCE, ECOSYSTEM, REACH DEMANDINSTALLED BASE APPSGENOMICS,
# ----------------------------------------------------------------------------------------
#
#
# Split 74, tokens None, triggered by: 0.04
# DRUG DISCOVERY DSL
# ----------------------------------------------------------------------------------------
#
#
# Split 75, tokens None, triggered by: 0.08
# CUDA-X LIBRARIES ONE ARCHITECTURE-CUDASUPERCOMPUTING SYSTEMS AND SOFTWARE GPU SWITCH NIC/DPU CPUWEATHER
# ----------------------------------------------------------------------------------------
#
#
# Split 76, tokens None, triggered by: 0.07
# SIMULATION
# ----------------------------------------------------------------------------------------
#
#
# Split 77, tokens None, triggered by: 0.06
# DSL6G,
# ----------------------------------------------------------------------------------------
#
#
# Split 78, tokens None, triggered by: 0.11
# QUANTUM
# ----------------------------------------------------------------------------------------
#
#
# Split 79, tokens None, triggered by: 0.17
# DSLAV, ROBOTICS, INDUSTRIAL DIGITAL
# ----------------------------------------------------------------------------------------
#
#
# Split 80, tokens None, triggered by: 0.13
# TWINS
# ----------------------------------------------------------------------------------------
#
#
# Split 81, tokens None, triggered by: 0.19
# DSLGENERATIVE AI
# ----------------------------------------------------------------------------------------
#
#
# Split 82, tokens None, triggered by: 0.19
# DSL DATACENTERS
# ----------------------------------------------------------------------------------------
#
#
# Split 83, tokens None, triggered by: 0.18
# HGX MGXCLOUD DGX CLOUD OV CLOUDEDGE AGX IGX“NVIDIA’s got great
# ----------------------------------------------------------------------------------------
#
#
# Split 84, tokens None, triggered by: 0.12
# chips, and more importantly, they have an incredible
# ----------------------------------------------------------------------------------------
#
#
# Split 85, tokens None, triggered by: 0.12
# ecosystem”
# ----------------------------------------------------------------------------------------
#
#
# Split 86, tokens None, triggered by: 0.02
# The New York Times
# ----------------------------------------------------------------------------------------
#
#
# Split 87, tokens None, triggered by: 0.05
# NVIDIA’s accelerated computing ecosystem is bringing AI to every enterprise.
# ----------------------------------------------------------------------------------------
#
#
# Split 88, tokens None, triggered by: 0.11
# The NVIDIA
# ----------------------------------------------------------------------------------------
#
#
# Split 89, tokens None, triggered by: 0.19
# ecosystem spans nearly 5 million  developers and 40,000  companies.
# ----------------------------------------------------------------------------------------
#
#
# Split 90, tokens None, triggered by: 0.08
# More than 1,600
# ----------------------------------------------------------------------------------------
#
#
# Split 91, tokens None, triggered by: 0.05
# generative AI companies are building on
# ----------------------------------------------------------------------------------------
#
#
# Split 92, tokens None, triggered by: 0.16
# NVIDIA. CUDA®, our parallel computing model
# ----------------------------------------------------------------------------------------
#
#
# Split 93, tokens None, triggered by: 0.20
# launched in 2006, offers developers more than 300  libraries, 600  AI models, numerous SDKs, and 3,500  GPU-accelerated applications. CUDA has more than 48 million  downloads.“NVIDIA’s prescription
# ----------------------------------------------------------------------------------------
#
#
# Split 94, tokens None, triggered by: 0.19
# for the future: transforming
# ----------------------------------------------------------------------------------------
#
#
# Split 95, tokens None, triggered by: 0.17
# healthcare with AI”
# ----------------------------------------------------------------------------------------
#
#
# Split 96, tokens None, triggered by: 0.13
# Forbes
# ----------------------------------------------------------------------------------------
#
#
# Split 97, tokens None, triggered by: 0.13
# NVIDIA AI is powering the next era of drug
# ----------------------------------------------------------------------------------------
#
#
# Split 98, tokens None, triggered by: -0.02
# discovery and advances in life sciences.
# ----------------------------------------------------------------------------------------
#
#
# Split 99, tokens None, triggered by: 0.19
# NVIDIA Clara™, our suite of computing platforms, software, and services for healthcare and life sciences, and NVIDIA BioNeMo™, our platform
# ----------------------------------------------------------------------------------------
#
#
# Split 100, tokens None, triggered by: 0.09
# for state-of-the-art generative AI models for drug discovery, are turbocharging breakthroughs. Genentech is tapping NVIDIA to use generative
# ----------------------------------------------------------------------------------------
#
#
# Split 101, tokens None, triggered by: 0.14
# AI to discover and develop new therapeutics and deliver treatments to patients more efficiently. Recursion Pharmaceuticals is the first NVIDIA
# ----------------------------------------------------------------------------------------
#
#
# Split 102, tokens None, triggered by: 0.14
# partner to offer an AI model through BioNeMo cloud APIs.
# ----------------------------------------------------------------------------------------
#
#
# Split 103, tokens None, triggered by: 0.14
# And Amgen is building AI models trained
# ----------------------------------------------------------------------------------------
#
#
# Split 104, tokens None, triggered by: 0.18
# to analyze one of the world’s most extensive
# ----------------------------------------------------------------------------------------
#
#
# Split 105, tokens None, triggered by: 0.09
# human datasets on an NVIDIA DGX SuperPOD™.“NVIDIA has virtually
# ----------------------------------------------------------------------------------------
#
#
# Split 106, tokens None, triggered by: 0.12
# recreated the entire planet—and now it
# ----------------------------------------------------------------------------------------
#
#
# Split 107, tokens None, triggered by: -0.01
# wants to use its digital
# ----------------------------------------------------------------------------------------
#
#
# Split 108, tokens None, triggered by: 0.12
# twin to crack weather
# ----------------------------------------------------------------------------------------
#
#
# Split 109, tokens None, triggered by: 0.17
# forecasting for good” TechRadar
# ----------------------------------------------------------------------------------------
#
#
# Split 110, tokens None, triggered by: 0.07
# NVIDIA AI is tackling climate change.
# ----------------------------------------------------------------------------------------
#
#
# Split 111, tokens None, triggered by: 0.08
# Extreme
# ----------------------------------------------------------------------------------------
#
#
# Split 112, tokens None, triggered by: 0.04
# events attributable to climate change cost more than $143 billion a year.
# ----------------------------------------------------------------------------------------
#
#
# Split 113, tokens None, triggered by: 0.03
# NVIDIA’s CorrDiff
# ----------------------------------------------------------------------------------------
#
#
# Split 114, tokens None, triggered by: 0.16
# is a revolutionary new generative AI model
# ----------------------------------------------------------------------------------------
#
#
# Split 115, tokens None, triggered by: 0.10
# trained on high-resolution radar, weather forecasts, and other data.
# ----------------------------------------------------------------------------------------
#
#
# Split 116, tokens None, triggered by: 0.01
# Using CorrDiff,
# ----------------------------------------------------------------------------------------
#
#
# Split 117, tokens None, triggered by: 0.16
# extreme weather events can be super-resolved from 25-kilometer to two-kilometer resolution with 1,000 times the speed and 3,000 times
# ----------------------------------------------------------------------------------------
#
#
# Split 118, tokens None, triggered by: 0.03
# the energy efficiency of conventional weather
# ----------------------------------------------------------------------------------------
#
#
# Split 119, tokens None, triggered by: 0.10
# models. This AI-powered weather forecasting allows us to more accurately predict and track severe storms to try and reduce those impacts.“NVIDIA is a core
# ----------------------------------------------------------------------------------------
#
#
# Split 120, tokens None, triggered by: 0.16
# technology leader in the autonomous driving arena” CleanTechnica
# ----------------------------------------------------------------------------------------
#
#
# Split 121, tokens None, triggered by: 0.15
# NVIDIA AI is revolutionizing transportation. NVIDIA has developed an end-to-end platform from cloud to car to allow the automotive ecosystem to develop industry-leading AI-
# ----------------------------------------------------------------------------------------
#
#
# Split 122, tokens None, triggered by: 0.09
# defined vehicles. We recently announced DRIVE
# ----------------------------------------------------------------------------------------
#
#
# Split 123, tokens None, triggered by: 0.11
# AGX Thor™—designed and optimized for gen AI utilizing NVIDIA’s Blackwell architecture— to reimagine the driving experience.
# ----------------------------------------------------------------------------------------
#
#
# Split 124, tokens None, triggered by: 0.11
# And this year, every next-generation
# ----------------------------------------------------------------------------------------
#
#
# Split 125, tokens None, triggered by: 0.14
# Mercedes-Benz vehicle will include an NVIDIA
# ----------------------------------------------------------------------------------------
#
#
# Split 126, tokens None, triggered by: 0.12
# software-defined computing architecture that includes the most powerful computer, system software, and applications for consumers.“The age of
# ----------------------------------------------------------------------------------------
#
#
# Split 127, tokens None, triggered by: 0.02
# humanoid robots
# ----------------------------------------------------------------------------------------
#
#
# Split 128, tokens None, triggered by: 0.17
# could be a significant
# ----------------------------------------------------------------------------------------
#
#
# Split 129, tokens None, triggered by: 0.14
# step closer thanks to a new release from NVIDIA” TechRadar
# ----------------------------------------------------------------------------------------
#
#
# Split 130, tokens None, triggered by: 0.19
# NVIDIA is fueling the next wave of AI—robotics and
# ----------------------------------------------------------------------------------------
#
#
# Split 131, tokens None, triggered by: 0.05
# industrial digitalization. And that new wave of robots that will learn in NVIDIA Omniverse. Simulators like Isaac Sim running on Omniverse will be gyms where
# ----------------------------------------------------------------------------------------
#
#
# Split 132, tokens None, triggered by: 0.17
# robots learn their skills.
# ----------------------------------------------------------------------------------------
#
#
# Split 133, tokens None, triggered by: 0.11
# Over 1.2 million developers and 10,000 customers and partners are leveraging
# ----------------------------------------------------------------------------------------
#
#
# Split 134, tokens None, triggered by: 0.18
# the NVIDIA Isaac and Jetson platforms to create
# ----------------------------------------------------------------------------------------
#
#
# Split 135, tokens None, triggered by: 0.12
# and deploy AI-driven robots. And Project GR00T, a
# ----------------------------------------------------------------------------------------
#
#
# Split 136, tokens None, triggered by: 0.09
# general-purpose foundation model for humanoid
# ----------------------------------------------------------------------------------------
#
#
# Split 137, tokens None, triggered by: 0.18
# robots, will help them understand natural language and emulate movements by observing human actions.“NVIDIA Omniverse
# ----------------------------------------------------------------------------------------
#
#
# Split 138, tokens None, triggered by: 0.12
# Cloud APIs will
# ----------------------------------------------------------------------------------------
#
#
# Split 139, tokens None, triggered by: 0.03
# elevate digital
# ----------------------------------------------------------------------------------------
#
#
# Split 140, tokens None, triggered by: 0.07
# twins for a new
# ----------------------------------------------------------------------------------------
#
#
# Split 141, tokens None, triggered by: 0.10
# industrial revolution” Venture Beat
# ----------------------------------------------------------------------------------------
#
#
# Split 142, tokens None, triggered by: 0.13
# The soul of NVIDIA is where computer graphics,
# ----------------------------------------------------------------------------------------
#
#
# Split 143, tokens None, triggered by: 0.16
# physics, and AI intersect in Omniverse—a virtual world simulation engine.
# ----------------------------------------------------------------------------------------
#
#
# Split 144, tokens None, triggered by: 0.17
# Heavy industry
# ----------------------------------------------------------------------------------------
#
#
# Split 145, tokens None, triggered by: 0.09
# is one of the final frontiers of IT. Omniverse is
# ----------------------------------------------------------------------------------------
#
#
# Split 146, tokens None, triggered by: 0.18
# the fundamental operating system for building
# ----------------------------------------------------------------------------------------
#
#
# Split 147, tokens None, triggered by: 0.02
# digital twins that are crucial to unlocking new
# ----------------------------------------------------------------------------------------
#
#
# Split 148, tokens None, triggered by: 0.06
# potential in heavy industries worldwide.
# ----------------------------------------------------------------------------------------
#
#
# Split 149, tokens None, triggered by: 0.13
# Omniverse connects the tools created by developers in the NVIDIA ecosystem.
# ----------------------------------------------------------------------------------------
#
#
# Split 150, tokens None, triggered by: 0.09
# It enables
# ----------------------------------------------------------------------------------------
#
#
# Split 151, tokens None, triggered by: 0.12
# each team to operate on the same ground
# ----------------------------------------------------------------------------------------
#
#
# Split 152, tokens None, triggered by: 0.19
# truth, creating efficiencies and innovation.
# ----------------------------------------------------------------------------------------
#
#
# Split 153, tokens None, triggered by: 0.07
# And
# ----------------------------------------------------------------------------------------
#
#
# Split 154, tokens None, triggered by: 0.19
# now, with NVIDIA Omniverse Cloud™ APIs, developers can simplify and speed up the
# ----------------------------------------------------------------------------------------
#
#
# Split 155, tokens None, triggered by: 0.20
# development of digital twins for almost any
# ----------------------------------------------------------------------------------------
#
#
# Split 156, tokens None, triggered by: 0.10
# industrial application, seamlessly integrating Omniverse into their existing apps.“Generative AI is the defining technology of
# ----------------------------------------------------------------------------------------
#
#
# Split 157, tokens None, triggered by: 0.09
# our time.
# ----------------------------------------------------------------------------------------
#
#
# Split 158, tokens None, triggered by: 0.18
# Blackwell is the engine to power this new industrial revolution. Working with the most dynamic companies in the world, we will realize the promise of AI for every industry.”The dawn of a new computing
# ----------------------------------------------------------------------------------------
#
#
# Split 159, tokens None, triggered by: 0.05
# era is unmistakably upon us.
# ----------------------------------------------------------------------------------------
#
#
# Split 160, tokens None, triggered by: 0.11
# Two transitions are occurring
# ----------------------------------------------------------------------------------------
#
#
# Split 161, tokens None, triggered by: 0.12
# simultaneously—accelerated computing
# ----------------------------------------------------------------------------------------
#
#
# Split 162, tokens None, triggered by: 0.18
# and generative AI—transforming the computer industry and every other industry worldwide.
# ----------------------------------------------------------------------------------------
#
#
# Split 163, tokens None, triggered by: 0.07
# CPU scaling, the engine that has driven the computer industry over the past three decades, has slowed. Software developers have turned to accelerated computing to keep pace with the exponentially growing demand for computing in a cost- and energy-sustainable way. The computing model pioneered by NVIDIA has
# ----------------------------------------------------------------------------------------
#
#
# Split 164, tokens None, triggered by: 0.18
# reached critical mass and has been adopted broadly as the path forward. Accelerated computing will modernize the world’s trillion-dollar data
# ----------------------------------------------------------------------------------------
#
#
# Split 165, tokens None, triggered by: 0.15
# center infrastructure.
# ----------------------------------------------------------------------------------------
#
#
# Split 166, tokens None, triggered by: 0.14
# Its increased
# ----------------------------------------------------------------------------------------
#
#
# Split 167, tokens None, triggered by: 0.04
# throughput and cost and energy savings are remarkable.
# ----------------------------------------------------------------------------------------
#
#
# Split 168, tokens None, triggered by: 0.08
# Two NVIDIA HGX computers with Hopper GPUs
# ----------------------------------------------------------------------------------------
#
#
# Split 169, tokens None, triggered by: 0.15
# that together cost $500K can replace 1,000 nodes of CPU servers that cost $10M for AI, scientific computing, or data processing workloads. For data centers that are budget- or
# ----------------------------------------------------------------------------------------
#
#
# Split 170, tokens None, triggered by: 0.17
# power-limited, NVIDIA delivers an order- of-magnitude increase in throughput. For data centers optimized for throughput, NVIDIA delivers an order-of-
# ----------------------------------------------------------------------------------------
#
#
# Split 171, tokens None, triggered by: 0.19
# magnitude reduction in cost and power.
# ----------------------------------------------------------------------------------------
#
#
# Split 172, tokens None, triggered by: 0.17
# Accelerated computing is the best way to build sustainable data centers.
# ----------------------------------------------------------------------------------------
#
#
# Split 173, tokens None, triggered by: 0.09
# When the cost of a fundamental resource, like computing, improves by
# ----------------------------------------------------------------------------------------
#
#
# Split 174, tokens None, triggered by: 0.15
# orders of magnitude, new methods
# ----------------------------------------------------------------------------------------
#
#
# Split 175, tokens None, triggered by: 0.15
# are invented, and new utilities are discovered. AI researchers tapped NVIDIA CUDA to realize deep learning, a machine learning algorithm that is incredibly compute-intensive. Deep learning processes mountains of data to find patterns and relationships and learn predictive features.
# ----------------------------------------------------------------------------------------
#
#
# Split 176, tokens None, triggered by: 0.12
# In
# ----------------------------------------------------------------------------------------
#
#
# Split 177, tokens None, triggered by: 0.19
# 2012, AlexNet shocked the artificial intelligence community by winning, by
# ----------------------------------------------------------------------------------------
#
#
# Split 178, tokens None, triggered by: 0.11
# a considerable margin, the ImageNet computer vision contest. Within a
# ----------------------------------------------------------------------------------------
#
#
# Split 179, tokens None, triggered by: 0.16
# couple of years, every computer vision algorithm used deep learning, and within five years, computer vision had achieved superhuman object recognition capabilities.
# ----------------------------------------------------------------------------------------
#
#
# Split 180, tokens None, triggered by: 0.07
# AlexNet on NVIDIA CUDA
# ----------------------------------------------------------------------------------------
#
#
# Split 181, tokens None, triggered by: 0.15
# was the big bang of modern AI. We recognized that AlexNet was more than a computer vision breakthrough. We imagined deep learning would fundamentally revolutionize software and, consequently, all computing.
# ----------------------------------------------------------------------------------------
#
#
# Split 182, tokens None, triggered by: 0.18
# Deep learning can scale to tackle many previously impossible challenges with
# ----------------------------------------------------------------------------------------
#
#
# Split 183, tokens None, triggered by: 0.07
# new network architecture innovations, more data, and more compute. In the ensuing decade, NVIDIA
# ----------------------------------------------------------------------------------------
#
#
# Split 184, tokens None, triggered by: 0.17
# set out to advance AI.
# ----------------------------------------------------------------------------------------
#
#
# Split 185, tokens None, triggered by: 0.12
# We
# ----------------------------------------------------------------------------------------
#
#
# Split 186, tokens None, triggered by: 0.17
# pursued several strategies:Reinvent every layer of computing ,
# ----------------------------------------------------------------------------------------
#
#
# Split 187, tokens None, triggered by: 0.05
# from GPU architecture, e.g., Tensor Cores, to system interconnect, e.g., NVLink, systems, e.g., DGX, software, e.g., cuDNN and TensorRT, to networking technologies, e.g., SHARP in-networking processing,
# ----------------------------------------------------------------------------------------
#
#
# Split 188, tokens None, triggered by: 0.09
# and much more. We reinvented computing from the ground up. Transform into a data-center-scale
# ----------------------------------------------------------------------------------------
#
#
# Split 189, tokens None, triggered by: 0.10
# company  by combining with Mellanox,
# ----------------------------------------------------------------------------------------
#
#
# Split 190, tokens None, triggered by: 0.19
# the world’s leading high-performance networking company. As computing
# ----------------------------------------------------------------------------------------
#
#
# Split 191, tokens None, triggered by: 0.19
# large models and training data scales to require millions of trillions more operations, we need not just amazing chips but AI supercomputing systems.
# ----------------------------------------------------------------------------------------
#
#
# Split 192, tokens None, triggered by: 0.10
# Today, NVIDIA is an expert at every computing layer, from chips to software, and across the data center —compute to networking.
# ----------------------------------------------------------------------------------------
#
#
# Split 193, tokens None, triggered by: 0.06
# We have the
# ----------------------------------------------------------------------------------------
#
#
# Split 194, tokens None, triggered by: 0.20
# expertise and scale to help customers
# ----------------------------------------------------------------------------------------
#
#
# Split 195, tokens None, triggered by: 0.13
# build AI infrastructures anywhere. Become an AI expert by building NVIDIA AI Research and application-specific AI platforms—full-stack AI platforms for DLSS RTX neural graphics, DRIVE AV self-driving cars, Isaac robotics, ACE digital humans, NeMo LLMs, BioNeMo digital biology, and Clara medical imaging—so that we can apply
# ----------------------------------------------------------------------------------------
#
#
# Split 196, tokens None, triggered by: 0.17
# AI firsthand to create new markets. Automotive has joined gaming as a
# ----------------------------------------------------------------------------------------
#
#
# Split 197, tokens None, triggered by: 0.10
# multi-billion-dollar run rate business. Healthcare and robotics are additional multi-billion-dollar opportunities.
# ----------------------------------------------------------------------------------------
#
#
# Split 198, tokens None, triggered by: 0.11
# Dear NVIDIANs
# ----------------------------------------------------------------------------------------
#
#
# Split 199, tokens None, triggered by: 0.19
# and Stakeholders,Build a new ecosystem for the AI era by creating tools, libraries, and expert technical teams to support developers
# ----------------------------------------------------------------------------------------
#
#
# Split 200, tokens None, triggered by: 0.16
# going after the AI revolution. The global NVIDIA ecosystem now approaches 5
# ----------------------------------------------------------------------------------------
#
#
# Split 201, tokens None, triggered by: 0.16
# million developers—capping a record- setting year for new developers.
# ----------------------------------------------------------------------------------------
#
#
# Split 202, tokens None, triggered by: 0.03
# Forty thousand companies have
# ----------------------------------------------------------------------------------------
#
#
# Split 203, tokens None, triggered by: 0.00
# worked with NVIDIA.
# ----------------------------------------------------------------------------------------
#
#
# Split 204, tokens None, triggered by: 0.10
# There are now
# ----------------------------------------------------------------------------------------
#
#
# Split 205, tokens None, triggered by: 0.11
# more than 3,300 GPU-accelerated
# ----------------------------------------------------------------------------------------
#
#
# Split 206, tokens None, triggered by: 0.13
# applications.
# ----------------------------------------------------------------------------------------
#
#
# Split 207, tokens None, triggered by: 0.03
# More than 18,000
# ----------------------------------------------------------------------------------------
#
#
# Split 208, tokens None, triggered by: 0.17
# startups are building on NVIDIA.
# ----------------------------------------------------------------------------------------
#
#
# Split 209, tokens None, triggered by: 0.18
# These four strategies—reinventing
# ----------------------------------------------------------------------------------------
#
#
# Split 210, tokens None, triggered by: 0.06
# the full computing stack, building data-center-scale AI supercomputers, conducting basic AI research and applying AI to create new markets, and building a global ecosystem—transformed
# ----------------------------------------------------------------------------------------
#
#
# Split 211, tokens None, triggered by: 0.16
# NVIDIA and all of computing. Twelve years after AlexNet, NVIDIA
# ----------------------------------------------------------------------------------------
#
#
# Split 212, tokens None, triggered by: 0.15
# is a full-stack, data-center-scale AI
# ----------------------------------------------------------------------------------------
#
#
# Split 213, tokens None, triggered by: 0.15
# company that partners with nearly every AI company in every industry worldwide.
# ----------------------------------------------------------------------------------------
#
#
# Split 214, tokens None, triggered by: 0.05
# Then ChatGPT arrived,
# ----------------------------------------------------------------------------------------
#
#
# Split 215, tokens None, triggered by: 0.04
# and the pace of AI accelerated even faster.
# ----------------------------------------------------------------------------------------
#
#
# Split 216, tokens None, triggered by: 0.18
# The era of generative AI began. Computers can now generate
# ----------------------------------------------------------------------------------------
#
#
# Split 217, tokens None, triggered by: 0.14
# information based on human prompts.
# ----------------------------------------------------------------------------------------
#
#
# Split 218, tokens None, triggered by: 0.12
# At the heart of ChatGPT, large
# ----------------------------------------------------------------------------------------
#
#
# Split 219, tokens None, triggered by: 0.04
# language models, or LLMs, learned to understand human language, prior knowledge, and even some common sense from massive amounts of text. And not only human language.
# ----------------------------------------------------------------------------------------
#
#
# Split 220, tokens None, triggered by: 0.12
# LLMs
# ----------------------------------------------------------------------------------------
#
#
# Split 221, tokens None, triggered by: 0.15
# have learned to understand text, speech,
# ----------------------------------------------------------------------------------------
#
#
# Split 222, tokens None, triggered by: 0.07
# images, and even amino acids and proteins, the language of biology.
# ----------------------------------------------------------------------------------------
#
#
# Split 223, tokens None, triggered by: 0.08
# With
# ----------------------------------------------------------------------------------------
#
#
# Split 224, tokens None, triggered by: 0.19
# multi-modal learning—for example, simultaneously learning from language and images—generative AI is gaining a deeper understanding of the world and
# ----------------------------------------------------------------------------------------
#
#
# Split 225, tokens None, triggered by: 0.12
# can translate across different modalities.
# ----------------------------------------------------------------------------------------
#
#
# Split 226, tokens None, triggered by: 0.13
# Given a prompt such as “ golden
# ----------------------------------------------------------------------------------------
#
#
# Split 227, tokens None, triggered by: 0.14
# retriever wearing sunglasses and a white golden doodle with black leather
# ----------------------------------------------------------------------------------------
#
#
# Split 228, tokens None, triggered by: 0.13
# jacket surfing a wave, on a surfboard
# ----------------------------------------------------------------------------------------
#
#
# Split 229, tokens None, triggered by: 0.08
# with NVIDIA logo, in Maui during sunset, with hotels on the beach ,”
# ----------------------------------------------------------------------------------------
#
#
# Split 230, tokens None, triggered by: 0.08
# generative AI can create an image. From an amino acid sequence, AI can generate the structure of a protein, e.g., the SARS-CoV-2 main protease.
# ----------------------------------------------------------------------------------------
#
#
# Split 231, tokens None, triggered by: 0.18
# The combinations and possibilities
# ----------------------------------------------------------------------------------------
#
#
# Split 232, tokens None, triggered by: 0.20
# are endless.
# ----------------------------------------------------------------------------------------
#
#
# Split 233, tokens None, triggered by: 0.16
# Generative AI is the most transformative and consequential technology of our generation.
# ----------------------------------------------------------------------------------------
#
#
# Split 234, tokens None, triggered by: 0.11
# Computers will
# ----------------------------------------------------------------------------------------
#
#
# Split 235, tokens None, triggered by: 0.13
# understand people and the world
# ----------------------------------------------------------------------------------------
#
#
# Split 236, tokens None, triggered by: 0.12
# and perform tasks that previously required human intelligence. With
# ----------------------------------------------------------------------------------------
#
#
# Split 237, tokens None, triggered by: 0.12
# generative AI, computers can augment and amplify humans to perform tasks with greater ease and speed, help us be more productive, and solve problems previously unimaginable.
# ----------------------------------------------------------------------------------------
#
#
# Split 238, tokens None, triggered by: 0.19
# Researchers use generative AI to compose billions of chemical compounds
# ----------------------------------------------------------------------------------------
#
#
# Split 239, tokens None, triggered by: 0.13
# and virtually test them as drugs against a disease target.
# ----------------------------------------------------------------------------------------
#
#
# Split 240, tokens None, triggered by: -0.00
# Climate scientists
# ----------------------------------------------------------------------------------------
#
#
# Split 241, tokens None, triggered by: 0.19
# are using generative AI to map tens of
# ----------------------------------------------------------------------------------------
#
#
# Split 242, tokens None, triggered by: 0.19
# thousands of potential trajectories of a
# ----------------------------------------------------------------------------------------
#
#
# Split 243, tokens None, triggered by: 0.06
# weather pattern in seconds to predict the path of a deadly storm better.
# ----------------------------------------------------------------------------------------
#
#
# Split 244, tokens None, triggered by: 0.14
# The automation of intelligence with generative AI will transform every
# ----------------------------------------------------------------------------------------
#
#
# Split 245, tokens None, triggered by: 0.15
# company in the world’s $100 trillion worth of industries.
# ----------------------------------------------------------------------------------------
#
#
# Split 246, tokens None, triggered by: 0.12
# Startups and established companies spanning every conceivable domain and industry are investing billions of dollars to
# ----------------------------------------------------------------------------------------
#
#
# Split 247, tokens None, triggered by: 0.16
# advance and apply generative AI. With AI supercomputers, we are manufacturing intelligence in the form
# ----------------------------------------------------------------------------------------
#
#
# Split 248, tokens None, triggered by: 0.00
# of tokens or floating-point numbers.
# ----------------------------------------------------------------------------------------
#
#
# Split 249, tokens None, triggered by: 0.16
# In the last industrial revolution, power generation plants produced electricity. In this new industrial revolution,
# ----------------------------------------------------------------------------------------
#
#
# Split 250, tokens None, triggered by: 0.03
# NVIDIA AI supercomputers are the AI factories that produce intelligence. Generative AI has enabled us to produce something completely new. Companies will operate a new type of facility, owned or rented, that
# ----------------------------------------------------------------------------------------
#
#
# Split 251, tokens None, triggered by: 0.11
# produces AI to augment, accelerate, and amplify the productivity of their employees and business processes.
# ----------------------------------------------------------------------------------------
#
#
# Split 252, tokens None, triggered by: 0.14
# Nations have awakened to AI’s impact. Countries are building sovereign AI infrastructures. Governments see AI factories as essential infrastructure to advance their society and local industries. Nations such as Canada, France, India, Singapore, Japan,
# ----------------------------------------------------------------------------------------
#
#
# Split 253, tokens None, triggered by: 0.14
# and others seek to develop their sovereign AI capabilities as they have recognized their country’s data is their most valuable natural resource.Generative AI is the most impactful
# ----------------------------------------------------------------------------------------
#
#
# Split 254, tokens None, triggered by: 0.05
# invention of our time, and as with electricity and the internet, it impacts everyone and every industry. The
# ----------------------------------------------------------------------------------------
#
#
# Split 255, tokens None, triggered by: 0.17
# potential of AI to help tackle the world’s most pressing challenges is incredible. To maximize this potential, companies,
# ----------------------------------------------------------------------------------------
#
#
# Split 256, tokens None, triggered by: 0.17
# governments, and societies are raising awareness of the capabilities of this technology, inventing capabilities to align, guardrail, secure, and control
# ----------------------------------------------------------------------------------------
#
#
# Split 257, tokens None, triggered by: 0.14
# models, sharing best practices, creating new policies, discovering new
# ----------------------------------------------------------------------------------------
#
#
# Split 258, tokens None, triggered by: 0.13
# social norms, encouraging debate,
# ----------------------------------------------------------------------------------------
#
#
# Split 259, tokens None, triggered by: 0.08
# and inspiring whole new areas of
# ----------------------------------------------------------------------------------------
#
#
# Split 260, tokens None, triggered by: -0.09
# research in AI security and safety.
# ----------------------------------------------------------------------------------------
#
#
# Split 261, tokens None, triggered by: 0.15
# NVIDIA Accelerated
# ----------------------------------------------------------------------------------------
#
#
# Split 262, tokens None, triggered by: 0.14
# Computing Reaches the Tipping Point
# ----------------------------------------------------------------------------------------
#
#
# Split 263, tokens None, triggered by: 0.18
# For fiscal 2024, revenue was up 126% to a record $60.9 billion.
# ----------------------------------------------------------------------------------------
#
#
# Split 264, tokens None, triggered by: 0.19
# GAAP earnings per diluted share was $11.93, up 586% from a year ago.
# ----------------------------------------------------------------------------------------
#
#
# Split 265, tokens None, triggered by: 0.14
# Non-GAAP earnings per diluted share were $12.96, up 288% from a year ago. Non-GAAP gross margin was 73.8%. Full-year Data Center revenue rose 217% to a record $47.5 billion. Demand for
# ----------------------------------------------------------------------------------------
#
#
# Split 266, tokens None, triggered by: 0.03
# Hopper architecture products remains
# ----------------------------------------------------------------------------------------
#
#
# Split 267, tokens None, triggered by: 0.12
# strong, and we have announced the
# ----------------------------------------------------------------------------------------
#
#
# Split 268, tokens None, triggered by: 0.17
# Blackwell architecture, its successor.Full-year Gaming revenue rose 15% to $10.4 billion on strong demand for
# ----------------------------------------------------------------------------------------
#
#
# Split 269, tokens None, triggered by: 0.06
# our expanded GeForce RTX 40 Series GPU lineup.
# ----------------------------------------------------------------------------------------
#
#
# Split 270, tokens None, triggered by: 0.04
# Full-year revenue for Professional Visualization rose 1% to $1.6 billion. Automotive full-year revenue this year rose 21% to $1.1 billion. A trillion dollars’ worth of existing data
# ----------------------------------------------------------------------------------------
#
#
# Split 271, tokens None, triggered by: 0.12
# centers needs to be accelerated, and a trillion more dollars is needed to expand the installed base with AI factories
# ----------------------------------------------------------------------------------------
#
#
# Split 272, tokens None, triggered by: 0.16
# in the next five years. We are in the
# ----------------------------------------------------------------------------------------
#
#
# Split 273, tokens None, triggered by: 0.13
# middle of one of the most significant
# ----------------------------------------------------------------------------------------
#
#
# Split 274, tokens None, triggered by: 0.14
# expansions in computing history.
# ----------------------------------------------------------------------------------------
#
#
# Split 275, tokens None, triggered by: 0.12
# NVIDIA
# ----------------------------------------------------------------------------------------
#
#
# Split 276, tokens None, triggered by: 0.15
# is well-positioned to help our customers and partners realize this opportunity.
# ----------------------------------------------------------------------------------------
#
#
# Split 277, tokens None, triggered by: 0.09
# We hosted GTC live and in person for
# ----------------------------------------------------------------------------------------
#
#
# Split 278, tokens None, triggered by: 0.17
# the first time in five years.
# ----------------------------------------------------------------------------------------
#
#
# Split 279, tokens None, triggered by: 0.15
# It was an
# ----------------------------------------------------------------------------------------
#
#
# Split 280, tokens None, triggered by: 0.10
# electric experience. Over 1,100 sessions, more than 300 exhibits, and 20-plus technical workshops packed the San Jose Convention Center to capacity,
# ----------------------------------------------------------------------------------------
#
#
# Split 281, tokens None, triggered by: 0.11
# providing learning and networking opportunities for our community and ecosystem unavailable anywhere else.
# ----------------------------------------------------------------------------------------
#
#
# Split 282, tokens None, triggered by: 0.17
# Just 15 years ago, GTC easily fit inside
# ----------------------------------------------------------------------------------------
#
#
# Split 283, tokens None, triggered by: 0.11
# a hotel ballroom.
# ----------------------------------------------------------------------------------------
#
#
# Split 284, tokens None, triggered by: -0.01
# Now, it is a can’t-
# ----------------------------------------------------------------------------------------
#
#
# Split 285, tokens None, triggered by: 0.08
# miss event with more than 19,000 in-person registrations, almost 300,000 virtual registrations, and more than 12,000 people at the
# ----------------------------------------------------------------------------------------
#
#
# Split 286, tokens None, triggered by: 0.04
# SAP Center for our keynote, which
# ----------------------------------------------------------------------------------------
#
#
# Split 287, tokens None, triggered by: 0.18
# kicked off an unbelievable week.
# ----------------------------------------------------------------------------------------
#
#
# Split 288, tokens None, triggered by: 0.12
# Our industry partners’ unprecedented collaboration and participation made
# ----------------------------------------------------------------------------------------
#
#
# Split 289, tokens None, triggered by: 0.09
# this year’s GTC exceptional. The
# ----------------------------------------------------------------------------------------
#
#
# Split 290, tokens None, triggered by: 0.07
# presence of industry giants like Amazon, Cisco, Dell, Google, HPE, IBM, Lenovo, Microsoft, Oracle, and
# ----------------------------------------------------------------------------------------
#
#
# Split 291, tokens None, triggered by: 0.18
# Supermicro at GTC underscored the
# ----------------------------------------------------------------------------------------
#
#
# Split 292, tokens None, triggered by: 0.15
# universal recognition of this moment in
# ----------------------------------------------------------------------------------------
#
#
# Split 293, tokens None, triggered by: 0.16
# technology and their commitment to shaping the future alongside NVIDIA. So, what now?
# ----------------------------------------------------------------------------------------
#
#
# Split 294, tokens None, triggered by: 0.07
# How are we raising the bar?
# ----------------------------------------------------------------------------------------
#
#
# Split 295, tokens None, triggered by: 0.18
# A New Computing Platform for the New Industrial Revolution We are accelerating our roadmap
# ----------------------------------------------------------------------------------------
#
#
# Split 296, tokens None, triggered by: 0.17
# across the board.
# ----------------------------------------------------------------------------------------
#
#
# Split 297, tokens None, triggered by: 0.06
# Generative AI models
# ----------------------------------------------------------------------------------------
#
#
# Split 298, tokens None, triggered by: 0.11
# are increasing exponentially in scale, doubling about every six months.
# ----------------------------------------------------------------------------------------
#
#
# Split 299, tokens None, triggered by: 0.06
# If
# ----------------------------------------------------------------------------------------
#
#
# Split 300, tokens None, triggered by: 0.11
# it takes twice as much data to train models twice as large, compute intensity
# ----------------------------------------------------------------------------------------
#
#
# Split 301, tokens None, triggered by: 0.06
# is growing at 4X every six months.
# ----------------------------------------------------------------------------------------
#
#
# Split 302, tokens None, triggered by: 0.20
# Further, the demand for inferencing,
# ----------------------------------------------------------------------------------------
#
#
# Split 303, tokens None, triggered by: 0.15
# or generating AI, on NVIDIA has
# ----------------------------------------------------------------------------------------
#
#
# Split 304, tokens None, triggered by: 0.15
# increased tremendously.
# ----------------------------------------------------------------------------------------
#
#
# Split 305, tokens None, triggered by: 0.12
# When you
# ----------------------------------------------------------------------------------------
#
#
# Split 306, tokens None, triggered by: 0.04
# interact with a chatbot, which every application or service will integrate in the future, you are likely interacting
# ----------------------------------------------------------------------------------------
#
#
# Split 307, tokens None, triggered by: 0.09
# directly with an NVIDIA GPU in the
# ----------------------------------------------------------------------------------------
#
#
# Split 308, tokens None, triggered by: 0.16
# cloud.
# ----------------------------------------------------------------------------------------
#
#
# Split 309, tokens None, triggered by: 0.19
# In the future, our interactions with computers will be generated by AI
# ----------------------------------------------------------------------------------------
#
#
# Split 310, tokens None, triggered by: 0.17
# specifically for that interaction rather
# ----------------------------------------------------------------------------------------
#
#
# Split 311, tokens None, triggered by: 0.12
# than retrieved prerecorded text or content.
# ----------------------------------------------------------------------------------------
#
#
# Split 312, tokens None, triggered by: 0.13
# Generative AI will let us reinvent how we interact with computers, and
# ----------------------------------------------------------------------------------------
#
#
# Split 313, tokens None, triggered by: 0.13
# demand for GPUs will be massive.
# ----------------------------------------------------------------------------------------
#
#
# Split 314, tokens None, triggered by: 0.20
# Multi-modality, large context windows, retrieval-augmented generation,
# ----------------------------------------------------------------------------------------
#
#
# Split 315, tokens None, triggered by: 0.05
# mixture-of-experts, synthetic data
# ----------------------------------------------------------------------------------------
#
#
# Split 316, tokens None, triggered by: 0.20
# generation, content protection,
# ----------------------------------------------------------------------------------------
#
#
# Split 317, tokens None, triggered by: 0.18
# reasoning, planning, tool use, physical world understanding, trillion-parameterLLMs, distillation to small models, high throughput to high interactivity—the
# ----------------------------------------------------------------------------------------
#
#
# Split 318, tokens None, triggered by: 0.07
# innovation rate of training and inference
# ----------------------------------------------------------------------------------------
#
#
# Split 319, tokens None, triggered by: 0.12
# is incredibly high.
# ----------------------------------------------------------------------------------------
#
#
# Split 320, tokens None, triggered by: 0.18
# Advances are
# ----------------------------------------------------------------------------------------
#
#
# Split 321, tokens None, triggered by: final split
# c
# ----------------------------------------------------------------------------------------

# %% [markdown]
# ### **Cumulative Chunking** <a id="section-eight"></a>

# %% [markdown]
# For Cumulative Chunking, we compare the embeddings of consecutive splits. We start by taking the embeddings of the first \( n \) splits and comparing them to the embedding of the \( n+1 \) split. If they are not similar, the first \( n \) splits are defined as a chunk, and we repeat the process with the subsequent splits. For example:
#
# - The embedding of split 1 is similar to the embedding of splits 1 and 2.
# - The embedding of splits 1 and 2 is similar to the embedding of splits 1, 2, and 3.
# - The embedding of splits 1, 2, and 3 is similar to the embedding of splits 1, 2, 3, and 4.
#
# In this case, splits 1, 2, and 3 are defined as a chunk, and we start the process again from split 4. While this method ensures that each chunk contains highly similar content, it takes longer to run compared to other chunking techniques.

# %%
chunker = CumulativeChunker(
    encoder=encoder, 
    score_threshold=0.2
)

# %%
chunks = chunker(docs=[content])
# Out:
#   0%|          | 0/650 [00:00<?, ?it/s]

# %%
chunker.print(chunks[0])
# Out:
# Split 1, tokens None, triggered by: 0.10
# 2024
# ----------------------------------------------------------------------------------------
#
#
# Split 2, tokens None, triggered by: 0.06
# NVIDIA Corporation Annual Review Notice of Annual Meeting
# ----------------------------------------------------------------------------------------
#
#
# Split 3, tokens None, triggered by: 0.08
# Proxy Statement
# ----------------------------------------------------------------------------------------
#
#
# Split 4, tokens None, triggered by: 0.08
# Form 10-K“The sum of all that
# ----------------------------------------------------------------------------------------
#
#
# Split 5, tokens None, triggered by: 0.17
# NVIDIA’s doing
# ----------------------------------------------------------------------------------------
#
#
# Split 6, tokens None, triggered by: 0.19
# will indeed create the next industrial
# ----------------------------------------------------------------------------------------
#
#
# Split 7, tokens None, triggered by: 0.04
# revolution”
# ----------------------------------------------------------------------------------------
#
#
# Split 8, tokens None, triggered by: 0.10
# CNBC
# ----------------------------------------------------------------------------------------
#
#
# Split 9, tokens None, triggered by: 0.17
# Accelerated computing is sustainable computing. Every data center in the world needs to be accelerated to reclaim power, achieve sustainability, and realize net-zero
# ----------------------------------------------------------------------------------------
#
#
# Split 10, tokens None, triggered by: 0.15
# emissions.
# ----------------------------------------------------------------------------------------
#
#
# Split 11, tokens None, triggered by: 0.19
# Accelerated data centers could save
# ----------------------------------------------------------------------------------------
#
#
# Split 12, tokens None, triggered by: 0.19
# an incredible 19 terawatt-hours of electricity annually if run on GPU and DPU accelerators vs CPUs. That’s about the same energy as a year’s
# ----------------------------------------------------------------------------------------
#
#
# Split 13, tokens None, triggered by: 0.14
# worth of trips by 2.9 million passenger cars.
# ----------------------------------------------------------------------------------------
#
#
# Split 14, tokens None, triggered by: 0.17
# The efficiency of accelerated computing
# ----------------------------------------------------------------------------------------
#
#
# Split 15, tokens None, triggered by: 0.15
# paved the way for generative AI.
# ----------------------------------------------------------------------------------------
#
#
# Split 16, tokens None, triggered by: 0.05
# The most
# ----------------------------------------------------------------------------------------
#
#
# Split 17, tokens None, triggered by: 0.13
# critical computing platform of our generation, generative AI will reshape the world’s largest industries and create an entirely new one. NVIDIA, the pioneer of accelerated computing, is the driving force of this new era.HGX B100 NVLINK Switch GB200 Superchip
# ----------------------------------------------------------------------------------------
#
#
# Split 18, tokens None, triggered by: 0.05
# Compute Node“They basically have
# ----------------------------------------------------------------------------------------
#
#
# Split 19, tokens None, triggered by: 0.10
# a comprehensive
# ----------------------------------------------------------------------------------------
#
#
# Split 20, tokens None, triggered by: 0.16
# solution from the chip
# ----------------------------------------------------------------------------------------
#
#
# Split 21, tokens None, triggered by: 0.20
# all the way to data centers at this point”
# ----------------------------------------------------------------------------------------
#
#
# Split 22, tokens None, triggered by: 0.12
# CIO
# ----------------------------------------------------------------------------------------
#
#
# Split 23, tokens None, triggered by: 0.04
# Accelerated computing starts with the most advanced processors and ends with AI factories. From chip architecture to advanced networking to acceleration libraries, NVIDIA builds the entire computing system at data-center scale.
# ----------------------------------------------------------------------------------------
#
#
# Split 24, tokens None, triggered by: 0.13
# Then, we
# ----------------------------------------------------------------------------------------
#
#
# Split 25, tokens None, triggered by: 0.15
# disaggregate everything and reintegrate it into
# ----------------------------------------------------------------------------------------
#
#
# Split 26, tokens None, triggered by: 0.12
# the world’s computing fabric so that industries can leverage the parts and systems they need. In the future, almost all of our experiences will be generative.
# ----------------------------------------------------------------------------------------
#
#
# Split 27, tokens None, triggered by: 0.02
# Blackwell—the world’s most powerful AI platform—is tailor-made for the generative AI revolution.
# ----------------------------------------------------------------------------------------
#
#
# Split 28, tokens None, triggered by: 0.14
# Quantum X800 Switch ConnectX-8 SuperNICSpectrum X800 Switch
# ----------------------------------------------------------------------------------------
#
#
# Split 29, tokens None, triggered by: 0.01
# BlueField-3 SuperNIC“Continually
# ----------------------------------------------------------------------------------------
#
#
# Split 30, tokens None, triggered by: 0.17
# optimized software
# ----------------------------------------------------------------------------------------
#
#
# Split 31, tokens None, triggered by: 0.06
# remains NVIDIA’s
# ----------------------------------------------------------------------------------------
#
#
# Split 32, tokens None, triggered by: 0.13
# ace in the hole”
# ----------------------------------------------------------------------------------------
#
#
# Split 33, tokens None, triggered by: 0.14
# Forbes
# ----------------------------------------------------------------------------------------
#
#
# Split 34, tokens None, triggered by: 0.20
# Accelerated computing requires full-stack
# ----------------------------------------------------------------------------------------
#
#
# Split 35, tokens None, triggered by: 0.10
# software.
# ----------------------------------------------------------------------------------------
#
#
# Split 36, tokens None, triggered by: 0.13
# NVIDIA’s acceleration stacks optimize workloads on a massive scale, integrating
# ----------------------------------------------------------------------------------------
#
#
# Split 37, tokens None, triggered by: 0.04
# thousands of nodes while treating network
# ----------------------------------------------------------------------------------------
#
#
# Split 38, tokens None, triggered by: 0.15
# and storage as integral components.
# ----------------------------------------------------------------------------------------
#
#
# Split 39, tokens None, triggered by: 0.18
# This year, we rolled out TensorRT-LLM and NVIDIA
# ----------------------------------------------------------------------------------------
#
#
# Split 40, tokens None, triggered by: 0.16
# Inference Microservices™ (NIM).
# ----------------------------------------------------------------------------------------
#
#
# Split 41, tokens None, triggered by: 0.05
# TensorRT-LLM
# ----------------------------------------------------------------------------------------
#
#
# Split 42, tokens None, triggered by: -0.03
# is an open-source software library that enables
# ----------------------------------------------------------------------------------------
#
#
# Split 43, tokens None, triggered by: 0.11
# customers to more than double the inference
# ----------------------------------------------------------------------------------------
#
#
# Split 44, tokens None, triggered by: 0.19
# performance of their GPUs.
# ----------------------------------------------------------------------------------------
#
#
# Split 45, tokens None, triggered by: 0.15
# NIM are a new way
# ----------------------------------------------------------------------------------------
#
#
# Split 46, tokens None, triggered by: 0.16
# to package and deliver AI software. This curated
# ----------------------------------------------------------------------------------------
#
#
# Split 47, tokens None, triggered by: 0.05
# selection of microservices adds a new layer
# ----------------------------------------------------------------------------------------
#
#
# Split 48, tokens None, triggered by: 0.10
# to NVIDIA’s full-stack computing platform—
# ----------------------------------------------------------------------------------------
#
#
# Split 49, tokens None, triggered by: 0.05
# connecting the AI ecosystem of model developers, platform providers, and enterprises with a standardized path to run custom AI models.Industry Standard APIs
# ----------------------------------------------------------------------------------------
#
#
# Split 50, tokens None, triggered by: 0.09
# Text, Speech, Image, Video, 3D, Biology
# ----------------------------------------------------------------------------------------
#
#
# Split 51, tokens None, triggered by: 0.14
# Triton Inference Server
# ----------------------------------------------------------------------------------------
#
#
# Split 52, tokens None, triggered by: 0.11
# cuDF, CV-CUDA, DALI, NCCL,
# ----------------------------------------------------------------------------------------
#
#
# Split 53, tokens None, triggered by: 0.04
# Post Processing Decoder
# ----------------------------------------------------------------------------------------
#
#
# Split 54, tokens None, triggered by: 0.09
# Cloud Native Stack
# ----------------------------------------------------------------------------------------
#
#
# Split 55, tokens None, triggered by: 0.06
# GPU Operator, Network Operator
# ----------------------------------------------------------------------------------------
#
#
# Split 56, tokens None, triggered by: 0.06
# Enterprise Management
# ----------------------------------------------------------------------------------------
#
#
# Split 57, tokens None, triggered by: 0.16
# GPU Health Check, Identity, Metrics, Monitoring, Secrets Management
# ----------------------------------------------------------------------------------------
#
#
# Split 58, tokens None, triggered by: 0.08
# Kubernetes
# ----------------------------------------------------------------------------------------
#
#
# Split 59, tokens None, triggered by: 0.20
# 100’s of Millions of CUDA GPUs Installed BaseTensorRT LLM and Triton cuBLAS , cuDNN, In-Flight Batching, Memory Optimization, FP8 Quantization Optimized Model Single GPU, Multi-GPU, Multi-Node
# ----------------------------------------------------------------------------------------
#
#
# Split 60, tokens None, triggered by: 0.07
# Customization Cache
# ----------------------------------------------------------------------------------------
#
#
# Split 61, tokens None, triggered by: 0.02
# P-Tuning, LORA, Model Weights
# ----------------------------------------------------------------------------------------
#
#
# Split 62, tokens None, triggered by: 0.13
# NVIDIA CUDA 100’s of Millions of CUDA GPUs Installed BaseDATA
# ----------------------------------------------------------------------------------------
#
#
# Split 63, tokens None, triggered by: 0.14
# PROCESSING DSLCAD, CAE, SDA DSLPERFORMANCE, ECOSYSTEM, REACH DEMANDINSTALLED BASE APPSGENOMICS,
# ----------------------------------------------------------------------------------------
#
#
# Split 64, tokens None, triggered by: 0.12
# DRUG DISCOVERY
# ----------------------------------------------------------------------------------------
#
#
# Split 65, tokens None, triggered by: 0.04
# DSL
# ----------------------------------------------------------------------------------------
#
#
# Split 66, tokens None, triggered by: 0.12
# CUDA-X LIBRARIES ONE ARCHITECTURE-CUDASUPERCOMPUTING SYSTEMS AND SOFTWARE GPU SWITCH NIC/DPU CPUWEATHER
# ----------------------------------------------------------------------------------------
#
#
# Split 67, tokens None, triggered by: 0.07
# SIMULATION
# ----------------------------------------------------------------------------------------
#
#
# Split 68, tokens None, triggered by: 0.06
# DSL6G,
# ----------------------------------------------------------------------------------------
#
#
# Split 69, tokens None, triggered by: 0.11
# QUANTUM
# ----------------------------------------------------------------------------------------
#
#
# Split 70, tokens None, triggered by: 0.04
# DSLAV, ROBOTICS, INDUSTRIAL DIGITAL
# ----------------------------------------------------------------------------------------
#
#
# Split 71, tokens None, triggered by: 0.13
# TWINS
# ----------------------------------------------------------------------------------------
#
#
# Split 72, tokens None, triggered by: 0.16
# DSLGENERATIVE AI DSL
# ----------------------------------------------------------------------------------------
#
#
# Split 73, tokens None, triggered by: 0.19
# DATACENTERS
# ----------------------------------------------------------------------------------------
#
#
# Split 74, tokens None, triggered by: 0.19
# HGX MGXCLOUD DGX CLOUD
# ----------------------------------------------------------------------------------------
#
#
# Split 75, tokens None, triggered by: 0.08
# OV CLOUDEDGE AGX IGXDATA PROCESSING DSLCAD, CAE, SDA DSLPERFORMANCE, ECOSYSTEM, REACH DEMANDINSTALLED BASE APPSGENOMICS,
# ----------------------------------------------------------------------------------------
#
#
# Split 76, tokens None, triggered by: 0.12
# DRUG DISCOVERY
# ----------------------------------------------------------------------------------------
#
#
# Split 77, tokens None, triggered by: 0.04
# DSL
# ----------------------------------------------------------------------------------------
#
#
# Split 78, tokens None, triggered by: 0.12
# CUDA-X LIBRARIES ONE ARCHITECTURE-CUDASUPERCOMPUTING SYSTEMS AND SOFTWARE GPU SWITCH NIC/DPU CPUWEATHER
# ----------------------------------------------------------------------------------------
#
#
# Split 79, tokens None, triggered by: 0.07
# SIMULATION
# ----------------------------------------------------------------------------------------
#
#
# Split 80, tokens None, triggered by: 0.06
# DSL6G,
# ----------------------------------------------------------------------------------------
#
#
# Split 81, tokens None, triggered by: 0.11
# QUANTUM
# ----------------------------------------------------------------------------------------
#
#
# Split 82, tokens None, triggered by: 0.04
# DSLAV, ROBOTICS, INDUSTRIAL DIGITAL
# ----------------------------------------------------------------------------------------
#
#
# Split 83, tokens None, triggered by: 0.13
# TWINS
# ----------------------------------------------------------------------------------------
#
#
# Split 84, tokens None, triggered by: 0.16
# DSLGENERATIVE AI DSL
# ----------------------------------------------------------------------------------------
#
#
# Split 85, tokens None, triggered by: 0.19
# DATACENTERS
# ----------------------------------------------------------------------------------------
#
#
# Split 86, tokens None, triggered by: 0.19
# HGX MGXCLOUD DGX CLOUD
# ----------------------------------------------------------------------------------------
#
#
# Split 87, tokens None, triggered by: 0.07
# OV CLOUDEDGE AGX IGX“NVIDIA’s got great
# ----------------------------------------------------------------------------------------
#
#
# Split 88, tokens None, triggered by: 0.09
# chips, and more importantly, they
# ----------------------------------------------------------------------------------------
#
#
# Split 89, tokens None, triggered by: 0.12
# have an incredible
# ----------------------------------------------------------------------------------------
#
#
# Split 90, tokens None, triggered by: 0.12
# ecosystem”
# ----------------------------------------------------------------------------------------
#
#
# Split 91, tokens None, triggered by: 0.02
# The New York Times
# ----------------------------------------------------------------------------------------
#
#
# Split 92, tokens None, triggered by: 0.12
# NVIDIA’s accelerated computing ecosystem is bringing AI to every enterprise. The NVIDIA ecosystem spans nearly 5 million  developers and 40,000  companies.
# ----------------------------------------------------------------------------------------
#
#
# Split 93, tokens None, triggered by: 0.08
# More than 1,600
# ----------------------------------------------------------------------------------------
#
#
# Split 94, tokens None, triggered by: 0.05
# generative AI companies are building on
# ----------------------------------------------------------------------------------------
#
#
# Split 95, tokens None, triggered by: 0.18
# NVIDIA. CUDA®, our parallel computing model
# ----------------------------------------------------------------------------------------
#
#
# Split 96, tokens None, triggered by: -0.03
# launched in 2006, offers developers more than 300  libraries, 600  AI models, numerous SDKs, and 3,500  GPU-accelerated applications. CUDA has more than 48 million  downloads.“NVIDIA’s prescription for the future:
# ----------------------------------------------------------------------------------------
#
#
# Split 97, tokens None, triggered by: 0.19
# transforming
# ----------------------------------------------------------------------------------------
#
#
# Split 98, tokens None, triggered by: 0.17
# healthcare with AI”
# ----------------------------------------------------------------------------------------
#
#
# Split 99, tokens None, triggered by: 0.13
# Forbes
# ----------------------------------------------------------------------------------------
#
#
# Split 100, tokens None, triggered by: 0.13
# NVIDIA AI is powering the next era of drug
# ----------------------------------------------------------------------------------------
#
#
# Split 101, tokens None, triggered by: -0.02
# discovery and advances in life sciences.
# ----------------------------------------------------------------------------------------
#
#
# Split 102, tokens None, triggered by: 0.19
# NVIDIA Clara™, our suite of computing platforms, software, and services for healthcare and life sciences, and NVIDIA BioNeMo™, our platform
# ----------------------------------------------------------------------------------------
#
#
# Split 103, tokens None, triggered by: 0.17
# for state-of-the-art generative AI models for drug discovery, are turbocharging breakthroughs. Genentech is tapping NVIDIA to use generative AI to discover and develop new therapeutics and deliver treatments to patients more efficiently. Recursion Pharmaceuticals is the first NVIDIA partner to offer an AI model through BioNeMo
# ----------------------------------------------------------------------------------------
#
#
# Split 104, tokens None, triggered by: 0.14
# cloud APIs.
# ----------------------------------------------------------------------------------------
#
#
# Split 105, tokens None, triggered by: 0.14
# And Amgen is building AI models trained
# ----------------------------------------------------------------------------------------
#
#
# Split 106, tokens None, triggered by: 0.18
# to analyze one of the world’s most extensive
# ----------------------------------------------------------------------------------------
#
#
# Split 107, tokens None, triggered by: 0.09
# human datasets on an NVIDIA DGX SuperPOD™.“NVIDIA has virtually
# ----------------------------------------------------------------------------------------
#
#
# Split 108, tokens None, triggered by: 0.06
# recreated the entire planet—and now it
# ----------------------------------------------------------------------------------------
#
#
# Split 109, tokens None, triggered by: -0.01
# wants to use its digital
# ----------------------------------------------------------------------------------------
#
#
# Split 110, tokens None, triggered by: 0.12
# twin to crack weather
# ----------------------------------------------------------------------------------------
#
#
# Split 111, tokens None, triggered by: 0.06
# forecasting for good” TechRadar NVIDIA AI is tackling climate change.
# ----------------------------------------------------------------------------------------
#
#
# Split 112, tokens None, triggered by: 0.08
# Extreme
# ----------------------------------------------------------------------------------------
#
#
# Split 113, tokens None, triggered by: 0.03
# events attributable to climate change cost more than $143 billion a year.
# ----------------------------------------------------------------------------------------
#
#
# Split 114, tokens None, triggered by: 0.03
# NVIDIA’s CorrDiff
# ----------------------------------------------------------------------------------------
#
#
# Split 115, tokens None, triggered by: 0.16
# is a revolutionary new generative AI model
# ----------------------------------------------------------------------------------------
#
#
# Split 116, tokens None, triggered by: 0.09
# trained on high-resolution radar, weather forecasts, and other data.
# ----------------------------------------------------------------------------------------
#
#
# Split 117, tokens None, triggered by: 0.01
# Using CorrDiff,
# ----------------------------------------------------------------------------------------
#
#
# Split 118, tokens None, triggered by: 0.17
# extreme weather events can be super-resolved from 25-kilometer to two-kilometer resolution
# ----------------------------------------------------------------------------------------
#
#
# Split 119, tokens None, triggered by: 0.16
# with 1,000 times the speed and 3,000 times
# ----------------------------------------------------------------------------------------
#
#
# Split 120, tokens None, triggered by: 0.03
# the energy efficiency of conventional weather
# ----------------------------------------------------------------------------------------
#
#
# Split 121, tokens None, triggered by: 0.19
# models. This AI-powered weather forecasting allows us to more accurately predict and track severe storms to try and reduce those impacts.“NVIDIA is a core
# ----------------------------------------------------------------------------------------
#
#
# Split 122, tokens None, triggered by: 0.17
# technology leader in the autonomous driving arena” CleanTechnica NVIDIA AI is revolutionizing transportation. NVIDIA has developed an end-to-end platform from cloud to car to allow the automotive ecosystem to develop industry-leading AI- defined vehicles. We recently announced DRIVE AGX Thor™—designed and optimized for gen AI utilizing NVIDIA’s Blackwell architecture— to reimagine the driving experience.
# ----------------------------------------------------------------------------------------
#
#
# Split 123, tokens None, triggered by: 0.11
# And this year, every next-generation
# ----------------------------------------------------------------------------------------
#
#
# Split 124, tokens None, triggered by: 0.14
# Mercedes-Benz vehicle will include an NVIDIA
# ----------------------------------------------------------------------------------------
#
#
# Split 125, tokens None, triggered by: 0.12
# software-defined computing architecture that includes the most powerful computer, system software, and applications for consumers.“The age of
# ----------------------------------------------------------------------------------------
#
#
# Split 126, tokens None, triggered by: 0.02
# humanoid robots
# ----------------------------------------------------------------------------------------
#
#
# Split 127, tokens None, triggered by: 0.17
# could be a significant
# ----------------------------------------------------------------------------------------
#
#
# Split 128, tokens None, triggered by: 0.16
# step closer thanks to a new release from NVIDIA”
# ----------------------------------------------------------------------------------------
#
#
# Split 129, tokens None, triggered by: 0.14
# TechRadar
# ----------------------------------------------------------------------------------------
#
#
# Split 130, tokens None, triggered by: 0.19
# NVIDIA is fueling the next wave of AI—robotics and
# ----------------------------------------------------------------------------------------
#
#
# Split 131, tokens None, triggered by: 0.09
# industrial digitalization. And that new wave of robots
# ----------------------------------------------------------------------------------------
#
#
# Split 132, tokens None, triggered by: 0.12
# that will learn in NVIDIA Omniverse. Simulators like Isaac Sim running on Omniverse will be gyms where robots learn their skills. Over 1.2 million developers
# ----------------------------------------------------------------------------------------
#
#
# Split 133, tokens None, triggered by: 0.11
# and 10,000 customers and partners are leveraging
# ----------------------------------------------------------------------------------------
#
#
# Split 134, tokens None, triggered by: 0.18
# the NVIDIA Isaac and Jetson platforms to create
# ----------------------------------------------------------------------------------------
#
#
# Split 135, tokens None, triggered by: 0.19
# and deploy AI-driven robots. And Project GR00T, a
# ----------------------------------------------------------------------------------------
#
#
# Split 136, tokens None, triggered by: 0.09
# general-purpose foundation model for humanoid
# ----------------------------------------------------------------------------------------
#
#
# Split 137, tokens None, triggered by: 0.09
# robots, will help them understand natural language and emulate movements by observing human actions.“NVIDIA Omniverse Cloud APIs will elevate digital
# ----------------------------------------------------------------------------------------
#
#
# Split 138, tokens None, triggered by: 0.07
# twins for a new
# ----------------------------------------------------------------------------------------
#
#
# Split 139, tokens None, triggered by: 0.02
# industrial revolution” Venture Beat
# ----------------------------------------------------------------------------------------
#
#
# Split 140, tokens None, triggered by: 0.13
# The soul of NVIDIA is where computer graphics,
# ----------------------------------------------------------------------------------------
#
#
# Split 141, tokens None, triggered by: 0.10
# physics, and AI intersect in Omniverse—a virtual world simulation engine.
# ----------------------------------------------------------------------------------------
#
#
# Split 142, tokens None, triggered by: 0.17
# Heavy industry
# ----------------------------------------------------------------------------------------
#
#
# Split 143, tokens None, triggered by: 0.12
# is one of the final frontiers of IT. Omniverse is
# ----------------------------------------------------------------------------------------
#
#
# Split 144, tokens None, triggered by: 0.18
# the fundamental operating system for building
# ----------------------------------------------------------------------------------------
#
#
# Split 145, tokens None, triggered by: 0.02
# digital twins that are crucial to unlocking new
# ----------------------------------------------------------------------------------------
#
#
# Split 146, tokens None, triggered by: 0.06
# potential in heavy industries worldwide.
# ----------------------------------------------------------------------------------------
#
#
# Split 147, tokens None, triggered by: 0.07
# Omniverse connects the tools created by developers in the NVIDIA ecosystem. It enables
# ----------------------------------------------------------------------------------------
#
#
# Split 148, tokens None, triggered by: 0.12
# each team to operate on the same ground
# ----------------------------------------------------------------------------------------
#
#
# Split 149, tokens None, triggered by: 0.19
# truth, creating efficiencies and innovation.
# ----------------------------------------------------------------------------------------
#
#
# Split 150, tokens None, triggered by: 0.07
# And
# ----------------------------------------------------------------------------------------
#
#
# Split 151, tokens None, triggered by: 0.18
# now, with NVIDIA Omniverse Cloud™ APIs, developers can simplify and speed up the development of digital twins for almost any
# ----------------------------------------------------------------------------------------
#
#
# Split 152, tokens None, triggered by: 0.04
# industrial application, seamlessly integrating Omniverse into their existing apps.“Generative AI is the defining technology of
# ----------------------------------------------------------------------------------------
#
#
# Split 153, tokens None, triggered by: 0.09
# our time.
# ----------------------------------------------------------------------------------------
#
#
# Split 154, tokens None, triggered by: 0.20
# Blackwell is the engine to power this new industrial revolution.
# ----------------------------------------------------------------------------------------
#
#
# Split 155, tokens None, triggered by: 0.14
# Working with the most dynamic companies in the world, we will realize the promise of AI for every industry.”The dawn of a new computing
# ----------------------------------------------------------------------------------------
#
#
# Split 156, tokens None, triggered by: 0.05
# era is unmistakably upon us.
# ----------------------------------------------------------------------------------------
#
#
# Split 157, tokens None, triggered by: 0.11
# Two transitions are occurring
# ----------------------------------------------------------------------------------------
#
#
# Split 158, tokens None, triggered by: 0.12
# simultaneously—accelerated computing
# ----------------------------------------------------------------------------------------
#
#
# Split 159, tokens None, triggered by: 0.20
# and generative AI—transforming the computer industry and every other industry worldwide. CPU scaling, the engine that has driven the computer industry over
# ----------------------------------------------------------------------------------------
#
#
# Split 160, tokens None, triggered by: 0.13
# the past three decades, has slowed. Software developers have turned to accelerated computing to keep pace with the exponentially growing demand for computing in a cost- and
# ----------------------------------------------------------------------------------------
#
#
# Split 161, tokens None, triggered by: 0.06
# energy-sustainable way. The computing model pioneered by NVIDIA has
# ----------------------------------------------------------------------------------------
#
#
# Split 162, tokens None, triggered by: 0.17
# reached critical mass and has been adopted broadly as the path forward. Accelerated computing will modernize
# ----------------------------------------------------------------------------------------
#
#
# Split 163, tokens None, triggered by: 0.18
# the world’s trillion-dollar data
# ----------------------------------------------------------------------------------------
#
#
# Split 164, tokens None, triggered by: 0.15
# center infrastructure.
# ----------------------------------------------------------------------------------------
#
#
# Split 165, tokens None, triggered by: 0.14
# Its increased
# ----------------------------------------------------------------------------------------
#
#
# Split 166, tokens None, triggered by: 0.14
# throughput and cost and energy savings are remarkable.
# ----------------------------------------------------------------------------------------
#
#
# Split 167, tokens None, triggered by: 0.07
# Two NVIDIA HGX computers with Hopper GPUs
# ----------------------------------------------------------------------------------------
#
#
# Split 168, tokens None, triggered by: 0.07
# that together cost $500K can replace 1,000 nodes of CPU servers that cost $10M for AI, scientific computing, or data processing workloads. For data centers that are budget- or
# ----------------------------------------------------------------------------------------
#
#
# Split 169, tokens None, triggered by: 0.08
# power-limited, NVIDIA delivers an order- of-magnitude increase in throughput. For data centers optimized for throughput, NVIDIA delivers an order-of- magnitude reduction in cost and power. Accelerated computing is the best way to build sustainable data centers.
# ----------------------------------------------------------------------------------------
#
#
# Split 170, tokens None, triggered by: 0.18
# When the cost of a fundamental resource, like computing, improves by
# ----------------------------------------------------------------------------------------
#
#
# Split 171, tokens None, triggered by: 0.15
# orders of magnitude, new methods
# ----------------------------------------------------------------------------------------
#
#
# Split 172, tokens None, triggered by: 0.11
# are invented, and new utilities are discovered. AI researchers tapped NVIDIA CUDA to realize deep learning, a machine learning algorithm that is incredibly compute-intensive. Deep learning processes mountains of data
# ----------------------------------------------------------------------------------------
#
#
# Split 173, tokens None, triggered by: 0.13
# to find patterns and relationships and learn predictive features.
# ----------------------------------------------------------------------------------------
#
#
# Split 174, tokens None, triggered by: 0.12
# In
# ----------------------------------------------------------------------------------------
#
#
# Split 175, tokens None, triggered by: 0.10
# 2012, AlexNet shocked the artificial intelligence community by winning, by a considerable margin, the ImageNet computer vision contest.
# ----------------------------------------------------------------------------------------
#
#
# Split 176, tokens None, triggered by: 0.11
# Within a
# ----------------------------------------------------------------------------------------
#
#
# Split 177, tokens None, triggered by: 0.17
# couple of years, every computer vision algorithm used deep learning, and within five years, computer vision had achieved superhuman object recognition
# ----------------------------------------------------------------------------------------
#
#
# Split 178, tokens None, triggered by: 0.16
# capabilities.
# ----------------------------------------------------------------------------------------
#
#
# Split 179, tokens None, triggered by: 0.07
# AlexNet on NVIDIA CUDA
# ----------------------------------------------------------------------------------------
#
#
# Split 180, tokens None, triggered by: 0.18
# was the big bang of modern AI. We recognized that AlexNet was more than a computer vision breakthrough. We imagined deep learning would fundamentally revolutionize software and, consequently, all computing. Deep learning can scale to tackle many
# ----------------------------------------------------------------------------------------
#
#
# Split 181, tokens None, triggered by: 0.18
# previously impossible challenges with
# ----------------------------------------------------------------------------------------
#
#
# Split 182, tokens None, triggered by: 0.17
# new network architecture innovations, more data, and more compute. In the ensuing decade, NVIDIA
# ----------------------------------------------------------------------------------------
#
#
# Split 183, tokens None, triggered by: 0.17
# set out to advance AI.
# ----------------------------------------------------------------------------------------
#
#
# Split 184, tokens None, triggered by: 0.12
# We
# ----------------------------------------------------------------------------------------
#
#
# Split 185, tokens None, triggered by: 0.17
# pursued several strategies:Reinvent every layer of computing ,
# ----------------------------------------------------------------------------------------
#
#
# Split 186, tokens None, triggered by: 0.03
# from GPU architecture, e.g., Tensor Cores, to system interconnect, e.g., NVLink, systems, e.g., DGX, software, e.g., cuDNN and TensorRT, to networking technologies, e.g., SHARP in-networking processing,
# ----------------------------------------------------------------------------------------
#
#
# Split 187, tokens None, triggered by: 0.18
# and much more. We reinvented
# ----------------------------------------------------------------------------------------
#
#
# Split 188, tokens None, triggered by: 0.10
# computing from the ground up. Transform into a data-center-scale
# ----------------------------------------------------------------------------------------
#
#
# Split 189, tokens None, triggered by: 0.10
# company  by combining with Mellanox,
# ----------------------------------------------------------------------------------------
#
#
# Split 190, tokens None, triggered by: 0.18
# the world’s leading high-performance networking company. As computing
# ----------------------------------------------------------------------------------------
#
#
# Split 191, tokens None, triggered by: -0.03
# large models and training data scales to require millions of trillions more operations, we need not just amazing chips but AI supercomputing systems. Today, NVIDIA is an expert at every computing layer, from chips to software, and across the data center —compute to networking.
# ----------------------------------------------------------------------------------------
#
#
# Split 192, tokens None, triggered by: 0.06
# We have the
# ----------------------------------------------------------------------------------------
#
#
# Split 193, tokens None, triggered by: 0.20
# expertise and scale to help customers
# ----------------------------------------------------------------------------------------
#
#
# Split 194, tokens None, triggered by: 0.15
# build AI infrastructures anywhere. Become an AI expert by building NVIDIA AI Research and application-specific AI platforms—full-stack AI platforms for DLSS RTX neural graphics, DRIVE AV self-driving cars, Isaac robotics, ACE digital humans, NeMo LLMs,
# ----------------------------------------------------------------------------------------
#
#
# Split 195, tokens None, triggered by: 0.11
# BioNeMo digital biology, and Clara medical imaging—so that we can apply
# ----------------------------------------------------------------------------------------
#
#
# Split 196, tokens None, triggered by: 0.10
# AI firsthand to create new markets. Automotive has joined gaming as a multi-billion-dollar run rate business. Healthcare and robotics are additional multi-billion-dollar opportunities.
# ----------------------------------------------------------------------------------------
#
#
# Split 197, tokens None, triggered by: 0.11
# Dear NVIDIANs
# ----------------------------------------------------------------------------------------
#
#
# Split 198, tokens None, triggered by: 0.13
# and Stakeholders,Build a new ecosystem for the AI era by creating tools, libraries, and expert technical teams to support developers going after the AI revolution. The global NVIDIA ecosystem now approaches 5 million developers—capping a record- setting year for new developers. Forty thousand companies have worked with NVIDIA.
# ----------------------------------------------------------------------------------------
#
#
# Split 199, tokens None, triggered by: 0.10
# There are now
# ----------------------------------------------------------------------------------------
#
#
# Split 200, tokens None, triggered by: 0.11
# more than 3,300 GPU-accelerated
# ----------------------------------------------------------------------------------------
#
#
# Split 201, tokens None, triggered by: 0.13
# applications.
# ----------------------------------------------------------------------------------------
#
#
# Split 202, tokens None, triggered by: 0.03
# More than 18,000
# ----------------------------------------------------------------------------------------
#
#
# Split 203, tokens None, triggered by: 0.17
# startups are building on NVIDIA.
# ----------------------------------------------------------------------------------------
#
#
# Split 204, tokens None, triggered by: 0.18
# These four strategies—reinventing
# ----------------------------------------------------------------------------------------
#
#
# Split 205, tokens None, triggered by: 0.20
# the full computing stack, building data-center-scale AI supercomputers, conducting basic AI research and applying AI to
# ----------------------------------------------------------------------------------------
#
#
# Split 206, tokens None, triggered by: 0.13
# create new markets, and building a global ecosystem—transformed
# ----------------------------------------------------------------------------------------
#
#
# Split 207, tokens None, triggered by: 0.01
# NVIDIA and all of computing. Twelve years after AlexNet, NVIDIA is a full-stack, data-center-scale AI company that partners with nearly every AI company in every industry worldwide.
# ----------------------------------------------------------------------------------------
#
#
# Split 208, tokens None, triggered by: 0.05
# Then ChatGPT arrived,
# ----------------------------------------------------------------------------------------
#
#
# Split 209, tokens None, triggered by: 0.10
# and the pace of AI accelerated even faster. The era of generative AI began. Computers can now generate information based on human prompts.
# ----------------------------------------------------------------------------------------
#
#
# Split 210, tokens None, triggered by: 0.12
# At the heart of ChatGPT, large
# ----------------------------------------------------------------------------------------
#
#
# Split 211, tokens None, triggered by: 0.17
# language models, or LLMs, learned to understand human language, prior knowledge, and even some common sense from massive amounts of text. And not only human language. LLMs have learned to understand text, speech,
# ----------------------------------------------------------------------------------------
#
#
# Split 212, tokens None, triggered by: 0.10
# images, and even amino acids and proteins, the language of biology.
# ----------------------------------------------------------------------------------------
#
#
# Split 213, tokens None, triggered by: 0.08
# With
# ----------------------------------------------------------------------------------------
#
#
# Split 214, tokens None, triggered by: 0.06
# multi-modal learning—for example, simultaneously learning from language and images—generative AI is gaining a deeper understanding of the world and can translate across different modalities.
# ----------------------------------------------------------------------------------------
#
#
# Split 215, tokens None, triggered by: 0.13
# Given a prompt such as “ golden
# ----------------------------------------------------------------------------------------
#
#
# Split 216, tokens None, triggered by: 0.16
# retriever wearing sunglasses and a white golden doodle with black leather jacket surfing a wave, on a surfboard
# ----------------------------------------------------------------------------------------
#
#
# Split 217, tokens None, triggered by: 0.09
# with NVIDIA logo, in Maui during sunset, with hotels on the beach ,”
# ----------------------------------------------------------------------------------------
#
#
# Split 218, tokens None, triggered by: 0.20
# generative AI can create an image. From an amino acid sequence, AI can generate the structure of a protein,
# ----------------------------------------------------------------------------------------
#
#
# Split 219, tokens None, triggered by: 0.08
# e.g., the SARS-CoV-2 main protease.
# ----------------------------------------------------------------------------------------
#
#
# Split 220, tokens None, triggered by: 0.18
# The combinations and possibilities
# ----------------------------------------------------------------------------------------
#
#
# Split 221, tokens None, triggered by: 0.20
# are endless.
# ----------------------------------------------------------------------------------------
#
#
# Split 222, tokens None, triggered by: 0.14
# Generative AI is the most transformative and consequential technology of
# ----------------------------------------------------------------------------------------
#
#
# Split 223, tokens None, triggered by: 0.16
# our generation.
# ----------------------------------------------------------------------------------------
#
#
# Split 224, tokens None, triggered by: 0.11
# Computers will
# ----------------------------------------------------------------------------------------
#
#
# Split 225, tokens None, triggered by: 0.13
# understand people and the world
# ----------------------------------------------------------------------------------------
#
#
# Split 226, tokens None, triggered by: 0.16
# and perform tasks that previously required human intelligence. With generative AI, computers can augment and amplify humans to perform tasks with greater ease and speed, help us be more productive, and solve
# ----------------------------------------------------------------------------------------
#
#
# Split 227, tokens None, triggered by: 0.12
# problems previously unimaginable.
# ----------------------------------------------------------------------------------------
#
#
# Split 228, tokens None, triggered by: 0.20
# Researchers use generative AI to compose billions of chemical compounds
# ----------------------------------------------------------------------------------------
#
#
# Split 229, tokens None, triggered by: 0.15
# and virtually test them as drugs against a disease target.
# ----------------------------------------------------------------------------------------
#
#
# Split 230, tokens None, triggered by: -0.00
# Climate scientists
# ----------------------------------------------------------------------------------------
#
#
# Split 231, tokens None, triggered by: 0.19
# are using generative AI to map tens of
# ----------------------------------------------------------------------------------------
#
#
# Split 232, tokens None, triggered by: 0.19
# thousands of potential trajectories of a
# ----------------------------------------------------------------------------------------
#
#
# Split 233, tokens None, triggered by: 0.06
# weather pattern in seconds to predict the path of a deadly storm better.
# ----------------------------------------------------------------------------------------
#
#
# Split 234, tokens None, triggered by: 0.14
# The automation of intelligence with generative AI will transform every
# ----------------------------------------------------------------------------------------
#
#
# Split 235, tokens None, triggered by: 0.16
# company in the world’s $100 trillion worth of industries.
# ----------------------------------------------------------------------------------------
#
#
# Split 236, tokens None, triggered by: 0.10
# Startups and established companies spanning every conceivable domain and industry are investing billions of dollars to
# ----------------------------------------------------------------------------------------
#
#
# Split 237, tokens None, triggered by: 0.16
# advance and apply generative AI. With AI supercomputers, we are manufacturing intelligence in the form
# ----------------------------------------------------------------------------------------
#
#
# Split 238, tokens None, triggered by: 0.00
# of tokens or floating-point numbers.
# ----------------------------------------------------------------------------------------
#
#
# Split 239, tokens None, triggered by: 0.11
# In the last industrial revolution, power generation plants produced electricity. In this new industrial revolution,
# ----------------------------------------------------------------------------------------
#
#
# Split 240, tokens None, triggered by: 0.10
# NVIDIA AI supercomputers are the AI factories that produce intelligence. Generative AI has enabled us to produce something completely new. Companies will operate a new type
# ----------------------------------------------------------------------------------------
#
#
# Split 241, tokens None, triggered by: 0.03
# of facility, owned or rented, that
# ----------------------------------------------------------------------------------------
#
#
# Split 242, tokens None, triggered by: 0.14
# produces AI to augment, accelerate, and amplify the productivity of their employees and business processes. Nations have awakened to AI’s impact. Countries are building sovereign AI infrastructures. Governments see AI factories as essential infrastructure
# ----------------------------------------------------------------------------------------
#
#
# Split 243, tokens None, triggered by: 0.16
# to advance their society and local industries. Nations such as Canada, France, India, Singapore, Japan, and others seek to develop their sovereign AI capabilities as they have recognized their country’s data is their most valuable natural resource.Generative AI is the most impactful
# ----------------------------------------------------------------------------------------
#
#
# Split 244, tokens None, triggered by: 0.14
# invention of our time, and as with electricity and the internet, it impacts everyone and every industry.
# ----------------------------------------------------------------------------------------
#
#
# Split 245, tokens None, triggered by: 0.05
# The
# ----------------------------------------------------------------------------------------
#
#
# Split 246, tokens None, triggered by: 0.11
# potential of AI to help tackle the world’s most pressing challenges is incredible. To maximize this potential, companies, governments, and societies are raising awareness of the capabilities of this technology, inventing capabilities to
# ----------------------------------------------------------------------------------------
#
#
# Split 247, tokens None, triggered by: 0.17
# align, guardrail, secure, and control
# ----------------------------------------------------------------------------------------
#
#
# Split 248, tokens None, triggered by: 0.15
# models, sharing best practices, creating new policies, discovering new social norms, encouraging debate, and inspiring whole new areas of
# ----------------------------------------------------------------------------------------
#
#
# Split 249, tokens None, triggered by: -0.09
# research in AI security and safety.
# ----------------------------------------------------------------------------------------
#
#
# Split 250, tokens None, triggered by: 0.15
# NVIDIA Accelerated
# ----------------------------------------------------------------------------------------
#
#
# Split 251, tokens None, triggered by: 0.18
# Computing Reaches the Tipping Point
# ----------------------------------------------------------------------------------------
#
#
# Split 252, tokens None, triggered by: 0.17
# For fiscal 2024, revenue was up 126% to a record $60.9 billion.
# ----------------------------------------------------------------------------------------
#
#
# Split 253, tokens None, triggered by: 0.04
# GAAP earnings per diluted share was $11.93, up 586% from a year ago. Non-GAAP earnings per diluted share were $12.96, up 288% from a year ago. Non-GAAP gross margin was 73.8%. Full-year Data Center revenue rose 217% to a record $47.5 billion.
# ----------------------------------------------------------------------------------------
#
#
# Split 254, tokens None, triggered by: 0.14
# Demand for
# ----------------------------------------------------------------------------------------
#
#
# Split 255, tokens None, triggered by: 0.03
# Hopper architecture products remains
# ----------------------------------------------------------------------------------------
#
#
# Split 256, tokens None, triggered by: 0.12
# strong, and we have announced the
# ----------------------------------------------------------------------------------------
#
#
# Split 257, tokens None, triggered by: 0.14
# Blackwell architecture, its successor.Full-year Gaming revenue rose 15% to $10.4 billion on strong demand for our expanded GeForce RTX 40 Series GPU lineup. Full-year revenue for Professional Visualization rose 1% to $1.6 billion. Automotive full-year revenue this year rose 21% to $1.1 billion. A trillion dollars’ worth of existing data
# ----------------------------------------------------------------------------------------
#
#
# Split 258, tokens None, triggered by: 0.09
# centers needs to be accelerated, and a trillion more dollars is needed to expand the installed base with AI factories in the next five years.
# ----------------------------------------------------------------------------------------
#
#
# Split 259, tokens None, triggered by: 0.16
# We are in the
# ----------------------------------------------------------------------------------------
#
#
# Split 260, tokens None, triggered by: 0.13
# middle of one of the most significant
# ----------------------------------------------------------------------------------------
#
#
# Split 261, tokens None, triggered by: 0.14
# expansions in computing history.
# ----------------------------------------------------------------------------------------
#
#
# Split 262, tokens None, triggered by: 0.12
# NVIDIA
# ----------------------------------------------------------------------------------------
#
#
# Split 263, tokens None, triggered by: 0.16
# is well-positioned to help our customers and partners realize this opportunity.
# ----------------------------------------------------------------------------------------
#
#
# Split 264, tokens None, triggered by: 0.09
# We hosted GTC live and in person for
# ----------------------------------------------------------------------------------------
#
#
# Split 265, tokens None, triggered by: 0.17
# the first time in five years.
# ----------------------------------------------------------------------------------------
#
#
# Split 266, tokens None, triggered by: 0.15
# It was an
# ----------------------------------------------------------------------------------------
#
#
# Split 267, tokens None, triggered by: 0.07
# electric experience. Over 1,100 sessions, more than 300 exhibits, and 20-plus technical workshops packed the San Jose Convention Center to capacity, providing learning and networking opportunities for our community and
# ----------------------------------------------------------------------------------------
#
#
# Split 268, tokens None, triggered by: 0.11
# ecosystem unavailable anywhere else.
# ----------------------------------------------------------------------------------------
#
#
# Split 269, tokens None, triggered by: 0.17
# Just 15 years ago, GTC easily fit inside
# ----------------------------------------------------------------------------------------
#
#
# Split 270, tokens None, triggered by: 0.11
# a hotel ballroom.
# ----------------------------------------------------------------------------------------
#
#
# Split 271, tokens None, triggered by: -0.01
# Now, it is a can’t-
# ----------------------------------------------------------------------------------------
#
#
# Split 272, tokens None, triggered by: 0.16
# miss event with more than 19,000 in-person registrations, almost 300,000 virtual registrations, and more than 12,000 people at the
# ----------------------------------------------------------------------------------------
#
#
# Split 273, tokens None, triggered by: 0.04
# SAP Center for our keynote, which
# ----------------------------------------------------------------------------------------
#
#
# Split 274, tokens None, triggered by: 0.18
# kicked off an unbelievable week.
# ----------------------------------------------------------------------------------------
#
#
# Split 275, tokens None, triggered by: 0.11
# Our industry partners’ unprecedented collaboration and participation made this year’s GTC exceptional. The presence of industry giants like Amazon, Cisco, Dell, Google, HPE, IBM, Lenovo, Microsoft, Oracle, and Supermicro at GTC underscored the
# ----------------------------------------------------------------------------------------
#
#
# Split 276, tokens None, triggered by: 0.15
# universal recognition of this moment in
# ----------------------------------------------------------------------------------------
#
#
# Split 277, tokens None, triggered by: 0.18
# technology and their commitment to shaping the future alongside NVIDIA.
# ----------------------------------------------------------------------------------------
#
#
# Split 278, tokens None, triggered by: 0.16
# So, what now?
# ----------------------------------------------------------------------------------------
#
#
# Split 279, tokens None, triggered by: 0.07
# How are we raising the bar?
# ----------------------------------------------------------------------------------------
#
#
# Split 280, tokens None, triggered by: 0.15
# A New Computing Platform for the New
# ----------------------------------------------------------------------------------------
#
#
# Split 281, tokens None, triggered by: 0.09
# Industrial Revolution We are accelerating our roadmap
# ----------------------------------------------------------------------------------------
#
#
# Split 282, tokens None, triggered by: 0.17
# across the board.
# ----------------------------------------------------------------------------------------
#
#
# Split 283, tokens None, triggered by: 0.06
# Generative AI models
# ----------------------------------------------------------------------------------------
#
#
# Split 284, tokens None, triggered by: 0.07
# are increasing exponentially in scale, doubling about every six months.
# ----------------------------------------------------------------------------------------
#
#
# Split 285, tokens None, triggered by: 0.06
# If
# ----------------------------------------------------------------------------------------
#
#
# Split 286, tokens None, triggered by: 0.18
# it takes twice as much data to train models twice as large, compute intensity
# ----------------------------------------------------------------------------------------
#
#
# Split 287, tokens None, triggered by: 0.06
# is growing at 4X every six months.
# ----------------------------------------------------------------------------------------
#
#
# Split 288, tokens None, triggered by: 0.20
# Further, the demand for inferencing,
# ----------------------------------------------------------------------------------------
#
#
# Split 289, tokens None, triggered by: 0.15
# or generating AI, on NVIDIA has
# ----------------------------------------------------------------------------------------
#
#
# Split 290, tokens None, triggered by: 0.15
# increased tremendously.
# ----------------------------------------------------------------------------------------
#
#
# Split 291, tokens None, triggered by: 0.12
# When you
# ----------------------------------------------------------------------------------------
#
#
# Split 292, tokens None, triggered by: 0.07
# interact with a chatbot, which every application or service will integrate in the future, you are likely interacting
# ----------------------------------------------------------------------------------------
#
#
# Split 293, tokens None, triggered by: 0.09
# directly with an NVIDIA GPU in the
# ----------------------------------------------------------------------------------------
#
#
# Split 294, tokens None, triggered by: 0.16
# cloud.
# ----------------------------------------------------------------------------------------
#
#
# Split 295, tokens None, triggered by: 0.09
# In the future, our interactions with computers will be generated by AI specifically for that interaction rather
# ----------------------------------------------------------------------------------------
#
#
# Split 296, tokens None, triggered by: 0.12
# than retrieved prerecorded text or content.
# ----------------------------------------------------------------------------------------
#
#
# Split 297, tokens None, triggered by: 0.18
# Generative AI will let us reinvent how we interact with computers, and demand for GPUs will be massive. Multi-modality, large context windows, retrieval-augmented generation, mixture-of-experts, synthetic data
# ----------------------------------------------------------------------------------------
#
#
# Split 298, tokens None, triggered by: 0.20
# generation, content protection,
# ----------------------------------------------------------------------------------------
#
#
# Split 299, tokens None, triggered by: 0.11
# reasoning, planning, tool use, physical world understanding, trillion-parameterLLMs, distillation to small models, high throughput to high interactivity—the innovation rate of training and inference
# ----------------------------------------------------------------------------------------
#
#
# Split 300, tokens None, triggered by: 0.12
# is incredibly high.
# ----------------------------------------------------------------------------------------
#
#
# Split 301, tokens None, triggered by: 0.18
# Advances are
# ----------------------------------------------------------------------------------------
#
#
# Split 302, tokens None, triggered by: final split
# c
# ----------------------------------------------------------------------------------------

# %% [markdown]
# ## **Step 6. Conclusion** <a id="section-nine"></a>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Roboto;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#               color:white;">
#               In conclusion, this notebook explored three semantic chunking techniques applied to parsing the 2024 NVIDIA annual report. Among them, statistical chunking emerged as the most effective, providing coherent and informative text chunks. This method proved efficient, delivering results in a reasonable timeframe compared to the other techniques tested. Its ability to dynamically adjust similarity thresholds contributed to producing meaningful content chunks without excessive processing time.
# </p>
# </div>
